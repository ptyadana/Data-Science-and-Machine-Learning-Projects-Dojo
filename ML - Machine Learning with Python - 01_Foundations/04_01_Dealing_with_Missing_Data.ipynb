# %% [markdown]
# # How to Deal with Missing Data in Python

# %% [markdown]
# ## Learning Objectives
# During the process of data exploration, it is not uncommon to realize that the data we have is incomplete. Missing data could arise as a result of changes in data collection methods, human error, bias, or simply the lack of reliable input. There are several ways to deal with missing data. By the end of the tutorial, you will have learned:
#
# + how to detect missing data
# + how to remove missing data
# + how to resolve missing data

# %% [markdown]
# ## How to Detect Missing Values

# %%
import pandas as pd

# %%
students = pd.read_excel("./data/students.xlsx", engine='openpyxl')
students
# Out:
#       ID  FirstName    LastName                Major              Minor   Age  \
# 0   1869       Hana      Barton              Finance                NaN  22.0
# 1   2010     Alicia      Kanuri           Management                NaN  21.0
# 2   2075      Becca     Swanson            Marketing                NaN  22.0
# 3   2228     Halima       Aminu   Business Analytics                NaN  20.0
# 4   2442      Holly    Robinson              Finance                NaN  20.0
# 5   2858      Carla     Harding          Accountancy                NaN   NaN
# 6   3459       Alex     Swanson          Accountancy                NaN   NaN
# 7   3585     Aminah       Zalim            Marketing                NaN  20.0
# 8   5170        Gus  Cunningham              Finance         Innovation  21.0
# 9   5317     Rafael       Solis   Business Analytics               ACMS   NaN
# 10  5336      Homer       White              Finance                NaN   NaN
# 11  5495       Lara       Woods          Accountancy                NaN   NaN
# 12  6453       Otis     Johnson           Management  Political Science  19.0
# 13  6504  Chantelle       Woods  Business Technology                NaN  18.0
# 14  6768   Caroline       Marsh   Business Analytics               ACMS  22.0
# 15  7511      Laila     Carroll            Marketing         Innovation  20.0
# 16  7965      Rocco      Decola              Finance         Innovation  21.0
# 17  9232      Julie      Holmes  Business Technology         Innovation  18.0
# 18  9268     Albert      Palmer           Management        Real Estate  21.0
# 19  9941       Zoya       Doyle   Business Analytics                NaN   NaN
#
#     Gender             City State      Zip
# 0   Female              NaN   NaN      NaN
# 1   Female  Berrien Springs   NaN      NaN
# 2   Female          Chicago    IL  60608.0
# 3   Female          Atlanta    GA  30303.0
# 4   Female        Charlotte    NC  28202.0
# 5   Female       Youngstown    OH  44502.0
# 6      NaN          Granger    IN      NaN
# 7   Female          Ashburn    VA  20147.0
# 8     Male        Massillon    OH  44646.0
# 9      NaN       South Bend    IN  46601.0
# 10    Male         St. Paul    MN  55101.0
# 11     NaN           Dallas    TX  75201.0
# 12    Male        Anchorage    AK  99501.0
# 13  Female          Chicago   NaN  60608.0
# 14  Female            Niles    MI      NaN
# 15  Female         New York    NY  10001.0
# 16    Male          Oakland    CA  94603.0
# 17  Female          Webster    NY  14580.0
# 18    Male          Detroit    MI  48201.0
# 19  Female          Chicago    IL  60608.0

# %%
# total missing values
students.isnull().sum()
# Out:
# ID            0
# FirstName     0
# LastName      0
# Major         0
# Minor        12
# Age           6
# Gender        3
# City          1
# State         3
# Zip           4
# dtype: int64

# %%
# find out which rows have mising values of State
mask = students['State'].isnull()
mask
# Out:
# 0      True
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13     True
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: State, dtype: bool

# %%
# find out which rows have mising values of State
students[mask]
# Out:
#       ID  FirstName LastName                Major Minor   Age  Gender  \
# 0   1869       Hana   Barton              Finance   NaN  22.0  Female
# 1   2010     Alicia   Kanuri           Management   NaN  21.0  Female
# 13  6504  Chantelle    Woods  Business Technology   NaN  18.0  Female
#
#                City State      Zip
# 0               NaN   NaN      NaN
# 1   Berrien Springs   NaN      NaN
# 13          Chicago   NaN  60608.0

# %% [markdown]
# ## How to Remove Missing Values

# %%
# dropping all rows if it has a missing values in any of the columns. This method is a bit extreme
students.dropna()
# Out:
#       ID FirstName    LastName                Major              Minor   Age  \
# 8   5170       Gus  Cunningham              Finance         Innovation  21.0
# 12  6453      Otis     Johnson           Management  Political Science  19.0
# 15  7511     Laila     Carroll            Marketing         Innovation  20.0
# 16  7965     Rocco      Decola              Finance         Innovation  21.0
# 17  9232     Julie      Holmes  Business Technology         Innovation  18.0
# 18  9268    Albert      Palmer           Management        Real Estate  21.0
#
#     Gender       City State      Zip
# 8     Male  Massillon    OH  44646.0
# 12    Male  Anchorage    AK  99501.0
# 15  Female   New York    NY  10001.0
# 16    Male    Oakland    CA  94603.0
# 17  Female    Webster    NY  14580.0
# 18    Male    Detroit    MI  48201.0

# %%
students
# Out:
#       ID  FirstName    LastName                Major              Minor   Age  \
# 0   1869       Hana      Barton              Finance                NaN  22.0
# 1   2010     Alicia      Kanuri           Management                NaN  21.0
# 2   2075      Becca     Swanson            Marketing                NaN  22.0
# 3   2228     Halima       Aminu   Business Analytics                NaN  20.0
# 4   2442      Holly    Robinson              Finance                NaN  20.0
# 5   2858      Carla     Harding          Accountancy                NaN   NaN
# 6   3459       Alex     Swanson          Accountancy                NaN   NaN
# 7   3585     Aminah       Zalim            Marketing                NaN  20.0
# 8   5170        Gus  Cunningham              Finance         Innovation  21.0
# 9   5317     Rafael       Solis   Business Analytics               ACMS   NaN
# 10  5336      Homer       White              Finance                NaN   NaN
# 11  5495       Lara       Woods          Accountancy                NaN   NaN
# 12  6453       Otis     Johnson           Management  Political Science  19.0
# 13  6504  Chantelle       Woods  Business Technology                NaN  18.0
# 14  6768   Caroline       Marsh   Business Analytics               ACMS  22.0
# 15  7511      Laila     Carroll            Marketing         Innovation  20.0
# 16  7965      Rocco      Decola              Finance         Innovation  21.0
# 17  9232      Julie      Holmes  Business Technology         Innovation  18.0
# 18  9268     Albert      Palmer           Management        Real Estate  21.0
# 19  9941       Zoya       Doyle   Business Analytics                NaN   NaN
#
#     Gender             City State      Zip
# 0   Female              NaN   NaN      NaN
# 1   Female  Berrien Springs   NaN      NaN
# 2   Female          Chicago    IL  60608.0
# 3   Female          Atlanta    GA  30303.0
# 4   Female        Charlotte    NC  28202.0
# 5   Female       Youngstown    OH  44502.0
# 6      NaN          Granger    IN      NaN
# 7   Female          Ashburn    VA  20147.0
# 8     Male        Massillon    OH  44646.0
# 9      NaN       South Bend    IN  46601.0
# 10    Male         St. Paul    MN  55101.0
# 11     NaN           Dallas    TX  75201.0
# 12    Male        Anchorage    AK  99501.0
# 13  Female          Chicago   NaN  60608.0
# 14  Female            Niles    MI      NaN
# 15  Female         New York    NY  10001.0
# 16    Male          Oakland    CA  94603.0
# 17  Female          Webster    NY  14580.0
# 18    Male          Detroit    MI  48201.0
# 19  Female          Chicago    IL  60608.0

# %% [markdown]
# ### Dropping subset of dataset

# %%
# we want to drop rows if there is missing values in State and Zip
# only row 0 and 1 should be dropped as they don't have both State and Zip values

students.dropna(subset=['State', 'Zip'], how='all')
# Out:
#       ID  FirstName    LastName                Major              Minor   Age  \
# 2   2075      Becca     Swanson            Marketing                NaN  22.0
# 3   2228     Halima       Aminu   Business Analytics                NaN  20.0
# 4   2442      Holly    Robinson              Finance                NaN  20.0
# 5   2858      Carla     Harding          Accountancy                NaN   NaN
# 6   3459       Alex     Swanson          Accountancy                NaN   NaN
# 7   3585     Aminah       Zalim            Marketing                NaN  20.0
# 8   5170        Gus  Cunningham              Finance         Innovation  21.0
# 9   5317     Rafael       Solis   Business Analytics               ACMS   NaN
# 10  5336      Homer       White              Finance                NaN   NaN
# 11  5495       Lara       Woods          Accountancy                NaN   NaN
# 12  6453       Otis     Johnson           Management  Political Science  19.0
# 13  6504  Chantelle       Woods  Business Technology                NaN  18.0
# 14  6768   Caroline       Marsh   Business Analytics               ACMS  22.0
# 15  7511      Laila     Carroll            Marketing         Innovation  20.0
# 16  7965      Rocco      Decola              Finance         Innovation  21.0
# 17  9232      Julie      Holmes  Business Technology         Innovation  18.0
# 18  9268     Albert      Palmer           Management        Real Estate  21.0
# 19  9941       Zoya       Doyle   Business Analytics                NaN   NaN
#
#     Gender        City State      Zip
# 2   Female     Chicago    IL  60608.0
# 3   Female     Atlanta    GA  30303.0
# 4   Female   Charlotte    NC  28202.0
# 5   Female  Youngstown    OH  44502.0
# 6      NaN     Granger    IN      NaN
# 7   Female     Ashburn    VA  20147.0
# 8     Male   Massillon    OH  44646.0
# 9      NaN  South Bend    IN  46601.0
# 10    Male    St. Paul    MN  55101.0
# 11     NaN      Dallas    TX  75201.0
# 12    Male   Anchorage    AK  99501.0
# 13  Female     Chicago   NaN  60608.0
# 14  Female       Niles    MI      NaN
# 15  Female    New York    NY  10001.0
# 16    Male     Oakland    CA  94603.0
# 17  Female     Webster    NY  14580.0
# 18    Male     Detroit    MI  48201.0
# 19  Female     Chicago    IL  60608.0

# %% [markdown]
# ### Dropping columns if there is any missing values

# %%
students.dropna(axis=1) # this is also extreme as most of our columns are dropped
# Out:
#       ID  FirstName    LastName                Major
# 0   1869       Hana      Barton              Finance
# 1   2010     Alicia      Kanuri           Management
# 2   2075      Becca     Swanson            Marketing
# 3   2228     Halima       Aminu   Business Analytics
# 4   2442      Holly    Robinson              Finance
# 5   2858      Carla     Harding          Accountancy
# 6   3459       Alex     Swanson          Accountancy
# 7   3585     Aminah       Zalim            Marketing
# 8   5170        Gus  Cunningham              Finance
# 9   5317     Rafael       Solis   Business Analytics
# 10  5336      Homer       White              Finance
# 11  5495       Lara       Woods          Accountancy
# 12  6453       Otis     Johnson           Management
# 13  6504  Chantelle       Woods  Business Technology
# 14  6768   Caroline       Marsh   Business Analytics
# 15  7511      Laila     Carroll            Marketing
# 16  7965      Rocco      Decola              Finance
# 17  9232      Julie      Holmes  Business Technology
# 18  9268     Albert      Palmer           Management
# 19  9941       Zoya       Doyle   Business Analytics

# %% [markdown]
# ### Dropping Columns using `thresh`

# %%
len(students.columns)
# Out:
# 10

# %%
# As we have 20 rows, we want to remove only 50% of the data if there is any missing values in the columns
# we can see that only the minor column is removed
students.dropna(axis=1, thresh=10)
# Out:
#       ID  FirstName    LastName                Major   Age  Gender  \
# 0   1869       Hana      Barton              Finance  22.0  Female
# 1   2010     Alicia      Kanuri           Management  21.0  Female
# 2   2075      Becca     Swanson            Marketing  22.0  Female
# 3   2228     Halima       Aminu   Business Analytics  20.0  Female
# 4   2442      Holly    Robinson              Finance  20.0  Female
# 5   2858      Carla     Harding          Accountancy   NaN  Female
# 6   3459       Alex     Swanson          Accountancy   NaN     NaN
# 7   3585     Aminah       Zalim            Marketing  20.0  Female
# 8   5170        Gus  Cunningham              Finance  21.0    Male
# 9   5317     Rafael       Solis   Business Analytics   NaN     NaN
# 10  5336      Homer       White              Finance   NaN    Male
# 11  5495       Lara       Woods          Accountancy   NaN     NaN
# 12  6453       Otis     Johnson           Management  19.0    Male
# 13  6504  Chantelle       Woods  Business Technology  18.0  Female
# 14  6768   Caroline       Marsh   Business Analytics  22.0  Female
# 15  7511      Laila     Carroll            Marketing  20.0  Female
# 16  7965      Rocco      Decola              Finance  21.0    Male
# 17  9232      Julie      Holmes  Business Technology  18.0  Female
# 18  9268     Albert      Palmer           Management  21.0    Male
# 19  9941       Zoya       Doyle   Business Analytics   NaN  Female
#
#                City State      Zip
# 0               NaN   NaN      NaN
# 1   Berrien Springs   NaN      NaN
# 2           Chicago    IL  60608.0
# 3           Atlanta    GA  30303.0
# 4         Charlotte    NC  28202.0
# 5        Youngstown    OH  44502.0
# 6           Granger    IN      NaN
# 7           Ashburn    VA  20147.0
# 8         Massillon    OH  44646.0
# 9        South Bend    IN  46601.0
# 10         St. Paul    MN  55101.0
# 11           Dallas    TX  75201.0
# 12        Anchorage    AK  99501.0
# 13          Chicago   NaN  60608.0
# 14            Niles    MI      NaN
# 15         New York    NY  10001.0
# 16          Oakland    CA  94603.0
# 17          Webster    NY  14580.0
# 18          Detroit    MI  48201.0
# 19          Chicago    IL  60608.0

# %% [markdown]
# ## How to Resolve Missing Values

# %% [markdown]
# ### Fill Values with specific value

# %%
# there are 3 missing values in Gender column
students['Gender'].isnull().sum()
# Out:
# 3

# %%
# fill those missing values with value Female
students = students.fillna({'Gender': 'Female'})
students
# Out:
#       ID  FirstName    LastName                Major              Minor   Age  \
# 0   1869       Hana      Barton              Finance                NaN  22.0
# 1   2010     Alicia      Kanuri           Management                NaN  21.0
# 2   2075      Becca     Swanson            Marketing                NaN  22.0
# 3   2228     Halima       Aminu   Business Analytics                NaN  20.0
# 4   2442      Holly    Robinson              Finance                NaN  20.0
# 5   2858      Carla     Harding          Accountancy                NaN   NaN
# 6   3459       Alex     Swanson          Accountancy                NaN   NaN
# 7   3585     Aminah       Zalim            Marketing                NaN  20.0
# 8   5170        Gus  Cunningham              Finance         Innovation  21.0
# 9   5317     Rafael       Solis   Business Analytics               ACMS   NaN
# 10  5336      Homer       White              Finance                NaN   NaN
# 11  5495       Lara       Woods          Accountancy                NaN   NaN
# 12  6453       Otis     Johnson           Management  Political Science  19.0
# 13  6504  Chantelle       Woods  Business Technology                NaN  18.0
# 14  6768   Caroline       Marsh   Business Analytics               ACMS  22.0
# 15  7511      Laila     Carroll            Marketing         Innovation  20.0
# 16  7965      Rocco      Decola              Finance         Innovation  21.0
# 17  9232      Julie      Holmes  Business Technology         Innovation  18.0
# 18  9268     Albert      Palmer           Management        Real Estate  21.0
# 19  9941       Zoya       Doyle   Business Analytics                NaN   NaN
#
#     Gender             City State      Zip
# 0   Female              NaN   NaN      NaN
# 1   Female  Berrien Springs   NaN      NaN
# 2   Female          Chicago    IL  60608.0
# 3   Female          Atlanta    GA  30303.0
# 4   Female        Charlotte    NC  28202.0
# 5   Female       Youngstown    OH  44502.0
# 6   Female          Granger    IN      NaN
# 7   Female          Ashburn    VA  20147.0
# 8     Male        Massillon    OH  44646.0
# 9   Female       South Bend    IN  46601.0
# 10    Male         St. Paul    MN  55101.0
# 11  Female           Dallas    TX  75201.0
# 12    Male        Anchorage    AK  99501.0
# 13  Female          Chicago   NaN  60608.0
# 14  Female            Niles    MI      NaN
# 15  Female         New York    NY  10001.0
# 16    Male          Oakland    CA  94603.0
# 17  Female          Webster    NY  14580.0
# 18    Male          Detroit    MI  48201.0
# 19  Female          Chicago    IL  60608.0

# %%
students['Gender'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Fill values with Medium Values

# %%
students['Age'].isnull().sum()
# Out:
# 6

# %%
students = students.fillna({'Age': students['Age'].mean()})

# %%
students['Age'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Fill missing values by Cell by Cell Approach
#
# We want to fill Zip code for row with `City=Granger & State=IN`

# %%
students
# Out:
#       ID  FirstName    LastName                Major              Minor  \
# 0   1869       Hana      Barton              Finance                NaN
# 1   2010     Alicia      Kanuri           Management                NaN
# 2   2075      Becca     Swanson            Marketing                NaN
# 3   2228     Halima       Aminu   Business Analytics                NaN
# 4   2442      Holly    Robinson              Finance                NaN
# 5   2858      Carla     Harding          Accountancy                NaN
# 6   3459       Alex     Swanson          Accountancy                NaN
# 7   3585     Aminah       Zalim            Marketing                NaN
# 8   5170        Gus  Cunningham              Finance         Innovation
# 9   5317     Rafael       Solis   Business Analytics               ACMS
# 10  5336      Homer       White              Finance                NaN
# 11  5495       Lara       Woods          Accountancy                NaN
# 12  6453       Otis     Johnson           Management  Political Science
# 13  6504  Chantelle       Woods  Business Technology                NaN
# 14  6768   Caroline       Marsh   Business Analytics               ACMS
# 15  7511      Laila     Carroll            Marketing         Innovation
# 16  7965      Rocco      Decola              Finance         Innovation
# 17  9232      Julie      Holmes  Business Technology         Innovation
# 18  9268     Albert      Palmer           Management        Real Estate
# 19  9941       Zoya       Doyle   Business Analytics                NaN
#
#           Age  Gender             City State      Zip
# 0   22.000000  Female              NaN   NaN      NaN
# 1   21.000000  Female  Berrien Springs   NaN      NaN
# 2   22.000000  Female          Chicago    IL  60608.0
# 3   20.000000  Female          Atlanta    GA  30303.0
# 4   20.000000  Female        Charlotte    NC  28202.0
# 5   20.357143  Female       Youngstown    OH  44502.0
# 6   20.357143  Female          Granger    IN      NaN
# 7   20.000000  Female          Ashburn    VA  20147.0
# 8   21.000000    Male        Massillon    OH  44646.0
# 9   20.357143  Female       South Bend    IN  46601.0
# 10  20.357143    Male         St. Paul    MN  55101.0
# 11  20.357143  Female           Dallas    TX  75201.0
# 12  19.000000    Male        Anchorage    AK  99501.0
# 13  18.000000  Female          Chicago   NaN  60608.0
# 14  22.000000  Female            Niles    MI      NaN
# 15  20.000000  Female         New York    NY  10001.0
# 16  21.000000    Male          Oakland    CA  94603.0
# 17  18.000000  Female          Webster    NY  14580.0
# 18  21.000000    Male          Detroit    MI  48201.0
# 19  20.357143  Female          Chicago    IL  60608.0

# %%
mask = (students['City'] == 'Granger') & (students['State']=='IN')

# %%
students.loc[mask, :]
# Out:
#      ID FirstName LastName        Major Minor        Age  Gender     City  \
# 6  3459      Alex  Swanson  Accountancy   NaN  20.357143  Female  Granger
#
#   State  Zip
# 6    IN  NaN

# %%
# updating with correct zip code

students.loc[mask, 'Zip'] = 46530
students
# Out:
#       ID  FirstName    LastName                Major              Minor  \
# 0   1869       Hana      Barton              Finance                NaN
# 1   2010     Alicia      Kanuri           Management                NaN
# 2   2075      Becca     Swanson            Marketing                NaN
# 3   2228     Halima       Aminu   Business Analytics                NaN
# 4   2442      Holly    Robinson              Finance                NaN
# 5   2858      Carla     Harding          Accountancy                NaN
# 6   3459       Alex     Swanson          Accountancy                NaN
# 7   3585     Aminah       Zalim            Marketing                NaN
# 8   5170        Gus  Cunningham              Finance         Innovation
# 9   5317     Rafael       Solis   Business Analytics               ACMS
# 10  5336      Homer       White              Finance                NaN
# 11  5495       Lara       Woods          Accountancy                NaN
# 12  6453       Otis     Johnson           Management  Political Science
# 13  6504  Chantelle       Woods  Business Technology                NaN
# 14  6768   Caroline       Marsh   Business Analytics               ACMS
# 15  7511      Laila     Carroll            Marketing         Innovation
# 16  7965      Rocco      Decola              Finance         Innovation
# 17  9232      Julie      Holmes  Business Technology         Innovation
# 18  9268     Albert      Palmer           Management        Real Estate
# 19  9941       Zoya       Doyle   Business Analytics                NaN
#
#           Age  Gender             City State      Zip
# 0   22.000000  Female              NaN   NaN      NaN
# 1   21.000000  Female  Berrien Springs   NaN      NaN
# 2   22.000000  Female          Chicago    IL  60608.0
# 3   20.000000  Female          Atlanta    GA  30303.0
# 4   20.000000  Female        Charlotte    NC  28202.0
# 5   20.357143  Female       Youngstown    OH  44502.0
# 6   20.357143  Female          Granger    IN  46530.0
# 7   20.000000  Female          Ashburn    VA  20147.0
# 8   21.000000    Male        Massillon    OH  44646.0
# 9   20.357143  Female       South Bend    IN  46601.0
# 10  20.357143    Male         St. Paul    MN  55101.0
# 11  20.357143  Female           Dallas    TX  75201.0
# 12  19.000000    Male        Anchorage    AK  99501.0
# 13  18.000000  Female          Chicago   NaN  60608.0
# 14  22.000000  Female            Niles    MI      NaN
# 15  20.000000  Female         New York    NY  10001.0
# 16  21.000000    Male          Oakland    CA  94603.0
# 17  18.000000  Female          Webster    NY  14580.0
# 18  21.000000    Male          Detroit    MI  48201.0
# 19  20.357143  Female          Chicago    IL  60608.0

# %% [markdown]
# #### now we want to update row 14 too

# %%
mask = (students['City'] == 'Niles') & (students['State'] == 'MI')

# %%
students.loc[mask, :]
# Out:
#       ID FirstName LastName               Major Minor   Age  Gender   City  \
# 14  6768  Caroline    Marsh  Business Analytics  ACMS  22.0  Female  Niles
#
#    State  Zip
# 14    MI  NaN

# %%
students.loc[mask, 'Zip'] = 49120
students
# Out:
#       ID  FirstName    LastName                Major              Minor  \
# 0   1869       Hana      Barton              Finance                NaN
# 1   2010     Alicia      Kanuri           Management                NaN
# 2   2075      Becca     Swanson            Marketing                NaN
# 3   2228     Halima       Aminu   Business Analytics                NaN
# 4   2442      Holly    Robinson              Finance                NaN
# 5   2858      Carla     Harding          Accountancy                NaN
# 6   3459       Alex     Swanson          Accountancy                NaN
# 7   3585     Aminah       Zalim            Marketing                NaN
# 8   5170        Gus  Cunningham              Finance         Innovation
# 9   5317     Rafael       Solis   Business Analytics               ACMS
# 10  5336      Homer       White              Finance                NaN
# 11  5495       Lara       Woods          Accountancy                NaN
# 12  6453       Otis     Johnson           Management  Political Science
# 13  6504  Chantelle       Woods  Business Technology                NaN
# 14  6768   Caroline       Marsh   Business Analytics               ACMS
# 15  7511      Laila     Carroll            Marketing         Innovation
# 16  7965      Rocco      Decola              Finance         Innovation
# 17  9232      Julie      Holmes  Business Technology         Innovation
# 18  9268     Albert      Palmer           Management        Real Estate
# 19  9941       Zoya       Doyle   Business Analytics                NaN
#
#           Age  Gender             City State      Zip
# 0   22.000000  Female              NaN   NaN      NaN
# 1   21.000000  Female  Berrien Springs   NaN      NaN
# 2   22.000000  Female          Chicago    IL  60608.0
# 3   20.000000  Female          Atlanta    GA  30303.0
# 4   20.000000  Female        Charlotte    NC  28202.0
# 5   20.357143  Female       Youngstown    OH  44502.0
# 6   20.357143  Female          Granger    IN  46530.0
# 7   20.000000  Female          Ashburn    VA  20147.0
# 8   21.000000    Male        Massillon    OH  44646.0
# 9   20.357143  Female       South Bend    IN  46601.0
# 10  20.357143    Male         St. Paul    MN  55101.0
# 11  20.357143  Female           Dallas    TX  75201.0
# 12  19.000000    Male        Anchorage    AK  99501.0
# 13  18.000000  Female          Chicago   NaN  60608.0
# 14  22.000000  Female            Niles    MI  49120.0
# 15  20.000000  Female         New York    NY  10001.0
# 16  21.000000    Male          Oakland    CA  94603.0
# 17  18.000000  Female          Webster    NY  14580.0
# 18  21.000000    Male          Detroit    MI  48201.0
# 19  20.357143  Female          Chicago    IL  60608.0
