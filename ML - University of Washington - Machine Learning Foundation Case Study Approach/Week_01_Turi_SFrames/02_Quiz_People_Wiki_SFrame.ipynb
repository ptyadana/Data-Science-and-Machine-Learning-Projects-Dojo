# %% [markdown]
# # Quiz - SFrames (People Wiki)

# %%
from turicreate import SFrame
import zipfile

# %% [markdown]
# ### 1. Download the Wiki People SFrame. Then open a new Jupyter notebook, import TuriCreate, and read the SFrame data.

# %%
zipref = zipfile.ZipFile('/content/people_wiki.sframe.zip')
zipref.extractall('./tmp/people_wiki')

# %%
data = SFrame(data='/content/tmp/people_wiki/people_wiki.sframe')

# %%
data.head(5)
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
#
# Rows: 5
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# +-------------------------------+---------------------+
# +-------------------------------+
# |              text             |
# +-------------------------------+
# | digby morrell born 10 octo... |
# | alfred j lewy aka sandy le... |
# | harpdog brown is a singer ... |
# | franz rottensteiner born i... |
# | henry krvits born 30 decem... |
# +-------------------------------+
# [5 rows x 3 columns]

# %% [markdown]
# ### 2. H​ow many rows are in the SFrame? (Do NOT use commas or periods.)

# %%
data
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
#
# Rows: 59071
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# | <http://dbpedia.org/resour... |    Sam Henderson    |
# | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | <http://dbpedia.org/resour... |     Grant Nelson    |
# | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +-------------------------------+---------------------+
# +-------------------------------+
# |              text             |
# +-------------------------------+
# ...

# %% [markdown]
# ### 3. Which name is in the last row?

# %%
data.tail()
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
#
# Rows: 10
#
# Data:
# +-------------------------------+-------------------------------+
# |              URI              |              name             |
# +-------------------------------+-------------------------------+
# | <http://dbpedia.org/resour... |            Rod Wilt           |
# | <http://dbpedia.org/resour... |      Scott Baker (judge)      |
# | <http://dbpedia.org/resour... |     Dragoljub Ojdani%C4%87    |
# | <http://dbpedia.org/resour... |           Oz Bengur           |
# | <http://dbpedia.org/resour... | Dee Brown (basketball, bor... |
# | <http://dbpedia.org/resour... |           Olari Elts          |
# | <http://dbpedia.org/resour... |         Scott F. Crago        |
# | <http://dbpedia.org/resour... |    David Cass (footballer)    |
# | <http://dbpedia.org/resour... |          Keith Elias          |
# | <http://dbpedia.org/resour... |          Fawaz Damrah         |
# ...

# %% [markdown]
# ### 4. Read the text column for Harpdog Brown. He was honored with:

# %%
data[data['name'] == 'Harpdog Brown']['text']
# Out:
# dtype: str
# Rows: ?
# ...

# %% [markdown]
# ### 5. Sort the SFrame according to the text column, in ascending order. What is the name entry in the first row?

# %%
data['text'].sort(ascending=True)
# Out:
# dtype: str
# Rows: 59071
# ...
