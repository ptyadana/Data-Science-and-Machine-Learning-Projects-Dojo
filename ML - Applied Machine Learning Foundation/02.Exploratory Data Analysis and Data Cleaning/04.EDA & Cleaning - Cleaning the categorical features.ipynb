# %% [markdown]
# ## EDA & Cleaning: Cleaning the categorical features
#
# Using the Titanic dataset from [this](https://www.kaggle.com/c/titanic/overview) Kaggle competition.
#
# This dataset contains information about 891 people who were on board the ship when departed on April 15th, 1912. As noted in the description on Kaggle's website, some people aboard the ship were more likely to survive the wreck than others. There were not enough lifeboats for everybody so women, children, and the upper-class were prioritized. Using the information about these 891 passengers, the challenge is to build a model to predict which people would survive based on the following fields:
#
# - **Name** (str) - Name of the passenger
# - **Pclass** (int) - Ticket class
# - **Sex** (str) - Sex of the passenger
# - **Age** (float) - Age in years
# - **SibSp** (int) - Number of siblings and spouses aboard
# - **Parch** (int) - Number of parents and children aboard
# - **Ticket** (str) - Ticket number
# - **Fare** (float) - Passenger fare
# - **Cabin** (str) - Cabin number
# - **Embarked** (str) - Port of embarkation (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# **This section focuses on cleaning up the `Sex`, `Cabin`, and `Embarked` features.**

# %% [markdown]
# ### Read in data

# %%
import pandas as pd
import numpy as np

titanic_df = pd.read_csv('../Data/titanic.csv')
titanic_df.drop(['Name', 'Ticket'], axis=1, inplace=True)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %% [markdown]
# ### Create indicator for `Cabin`

# %%
# assigned cabin indicator based on cabin value Null or not
titanic_df['Cabin_ind'] = np.where(titanic_df['Cabin'].isnull(), 0, 1)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked  Cabin_ind
# 0        S          0
# 1        C          1
# 2        S          0
# 3        S          1
# 4        S          0

# %% [markdown]
# ### Convert `Sex` to numeric

# %%
# sometimes model have issue handling categorical values, so we have to map it to numeric value
gender_num = {'male': 0, 'female': 1}

# %%
titanic_df['Sex'] = titanic_df['Sex'].map(gender_num)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    0  22.0      1      0   7.2500   NaN
# 1            2         1       1    1  38.0      1      0  71.2833   C85
# 2            3         1       3    1  26.0      0      0   7.9250   NaN
# 3            4         1       1    1  35.0      1      0  53.1000  C123
# 4            5         0       3    0  35.0      0      0   8.0500   NaN
#
#   Embarked  Cabin_ind
# 0        S          0
# 1        C          1
# 2        S          0
# 3        S          1
# 4        S          0

# %% [markdown]
# ### Drop `Cabin` and `Embarked`

# %%
# As we already had Cabin indicator, we will remove Cabin
# For Embarked, it have no caucal effect on the survival, so we will also remove it
titanic_df.drop(['Cabin', 'Embarked'], axis=1, inplace=True)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Cabin_ind
# 0            1         0       3    0  22.0      1      0   7.2500          0
# 1            2         1       1    1  38.0      1      0  71.2833          1
# 2            3         1       3    1  26.0      0      0   7.9250          0
# 3            4         1       1    1  35.0      1      0  53.1000          1
# 4            5         0       3    0  35.0      0      0   8.0500          0
