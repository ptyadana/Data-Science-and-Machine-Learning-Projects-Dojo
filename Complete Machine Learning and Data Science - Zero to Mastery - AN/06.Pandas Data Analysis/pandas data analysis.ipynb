# %%
import pandas as pd

# %% [markdown]
# ## 2 Main Data Types (Series and DataFrame)

# %%
# 2 main data types
series = pd.Series(['BMW', 'Toyota', 'Honda'])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
# series are 1 dimensional 

colors = pd.Series(['Blue', 'Red', 'Yellow'])

# %%
colors
# Out:
# 0      Blue
# 1       Red
# 2    Yellow
# dtype: object

# %%
#  Exercise 1) Series of different foods
foods = pd.Series(['Banana', 'Apple', 'Orange'])
foods
# Out:
# 0    Banana
# 1     Apple
# 2    Orange
# dtype: object

# %%
# Exercise 2) Series of different dollar values
dollars = pd.Series([1.1, 2.565, 7.9])
dollars
# Out:
# 0    1.100
# 1    2.565
# 2    7.900
# dtype: float64

# %%
# Exercise 3) Foods and dollar values
food_prices = pd.DataFrame({'foods': foods, 'dollars': dollars})
food_prices
# Out:
#     foods  dollars
# 0  Banana    1.100
# 1   Apple    2.565
# 2  Orange    7.900

# %%
# DataFrame = 2 dimensional

car_data = pd.DataFrame({'Car make': series, 'Colour': colors})
car_data
# Out:
#   Car make  Colour
# 0      BMW    Blue
# 1   Toyota     Red
# 2    Honda  Yellow

# %%
# Import data

car_sales = pd.read_csv('car-sales.csv')

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Exporting DataFrame

# %%
# Exporting DataFrame

car_sales.to_csv('exported-cars-sales.csv', index = False)
#car_sales.to_excel()

# %%
# data from URL

heart_info = pd.read_csv('https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv')
heart_info
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ### Exercises
# Practice importing a .csv file using pd.read_csv(), you can download heart-disease.csv.
# This file contains annonymous patient medical records and whether or not they have heart disease.
# Practice exporting a DataFrame using .to_csv(). You could export the heart disease DataFrame after you've imported it.

# %%
patient_data = pd.read_csv('heart-diseases.csv')
patient_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
patient_data.to_csv('exported-heart-diseases.csv')

# %% [markdown]
# ## Describe Data with Pandas

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns

# %%
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices = pd.Series([1000, 2000, 5000])
car_prices.mean()
# Out:
# 2666.6666666666665

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales['Doors'].sum()
# Out:
# 40

# %%
car_sales['Odometer (KM)'].sum()
# Out:
# 786014

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales['Doors'].mean()
# Out:
# 4.0

# %% [markdown]
# ## Selecting and Viewig Data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
car_sales.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ### loc vs iloc
#
# loc : refer to index number which can be explicitly defined.
# .loc[] takes an integer as input. And it chooses from your Series or DataFrame whichever index matches the number.
#
# iloc: refer to actual position
# iloc[] does a similar thing but works with exact positions.
#
#
# ### When should you use .loc[] or .iloc[]?
#
# - Use .loc[] when you're referring to **indexes** .
# - Use .iloc[] when you're referring to **positions** in the DataFrame (index is out of order).

# %%
# .loc and .iloc
animals = pd.Series(['Dog', 'Cat', 'Bird', 'Panda'], index=[0,3,8,3])
animals
# Out:
# 0      Dog
# 3      Cat
# 8     Bird
# 3    Panda
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      Cat
# 3    Panda
# dtype: object

# %%
animals.loc[8]
# Out:
# 'Bird'

# %%
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# iloc
# select row at position 2
animals.iloc[2]
# Out:
# 'Bird'

# %%
animals
# Out:
# 0      Dog
# 3      Cat
# 8     Bird
# 3    Panda
# dtype: object

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals
# Out:
# 0      Dog
# 3      Cat
# 8     Bird
# 3    Panda
# dtype: object

# %%
animals.iloc[:2]
# Out:
# 0    Dog
# 3    Cat
# dtype: object

# %%
animals.loc[:8]
# Out:
# 0     Dog
# 3     Cat
# 8    Bird
# dtype: object

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales['Colour']
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales.Make == 'Toyota']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Comparing two columns

# %%
pd.crosstab(car_sales['Make'], car_sales['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %% [markdown]
# ### Groupby

# %%
car_sales.groupby(['Make']).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales['Odometer (KM)'].plot()

# %%
car_sales['Odometer (KM)'].hist()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['NewPrice'] = car_sales['Price'].str.replace('[\$\,]', '').astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice
# 0  Toyota  White         150043      4   $4,000.00    4000.0
# 1   Honda    Red          87899      4   $5,000.00    5000.0
# 2  Toyota   Blue          32549      3   $7,000.00    7000.0
# 3     BMW  Black          11179      5  $22,000.00   22000.0
# 4  Nissan  White         213095      4   $3,500.00    3500.0
# 5  Toyota  Green          99213      4   $4,500.00    4500.0
# 6   Honda   Blue          45698      4   $7,500.00    7500.0
# 7   Honda   Blue          54738      4   $7,000.00    7000.0
# 8  Toyota  White          60000      4   $6,250.00    6250.0
# 9  Nissan  White          31600      4   $9,700.00    9700.0

# %%
car_sales['NewPrice1'] = car_sales['Price'].str.replace('[\$.*(\.\d*)*]', '').astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-59-8d9362df372a> in <module>
# ----> 1 car_sales['NewPrice1'] = car_sales['Price'].str.replace('[\$.*(\.\d*)*]', '').astype(int)
#
# ~\.conda\envs\venv-datascience\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\.conda\envs\venv-datascience\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
# ...

# %%
car_sales["NewPrice2"] = car_sales["Price"].str.replace('[\$\,\.]', '').astype(int)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice  NewPrice2
# 0  Toyota  White         150043      4   $4,000.00    4000.0     400000
# 1   Honda    Red          87899      4   $5,000.00    5000.0     500000
# 2  Toyota   Blue          32549      3   $7,000.00    7000.0     700000
# 3     BMW  Black          11179      5  $22,000.00   22000.0    2200000
# 4  Nissan  White         213095      4   $3,500.00    3500.0     350000
# 5  Toyota  Green          99213      4   $4,500.00    4500.0     450000
# 6   Honda   Blue          45698      4   $7,500.00    7500.0     750000
# 7   Honda   Blue          54738      4   $7,000.00    7000.0     700000
# 8  Toyota  White          60000      4   $6,250.00    6250.0     625000
# 9  Nissan  White          31600      4   $9,700.00    9700.0     970000

# %%
car_sales['NewPrice'].plot()

# %% [markdown]
# ## Manipulating data

# %%
car_sales['Make'].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice  NewPrice2
# 0  Toyota  White         150043      4   $4,000.00    4000.0     400000
# 1   Honda    Red          87899      4   $5,000.00    5000.0     500000
# 2  Toyota   Blue          32549      3   $7,000.00    7000.0     700000
# 3     BMW  Black          11179      5  $22,000.00   22000.0    2200000
# 4  Nissan  White         213095      4   $3,500.00    3500.0     350000
# 5  Toyota  Green          99213      4   $4,500.00    4500.0     450000
# 6   Honda   Blue          45698      4   $7,500.00    7500.0     750000
# 7   Honda   Blue          54738      4   $7,000.00    7000.0     700000
# 8  Toyota  White          60000      4   $6,250.00    6250.0     625000
# 9  Nissan  White          31600      4   $9,700.00    9700.0     970000

# %%
car_sales['Make'] = car_sales['Make'].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice  NewPrice2
# 0  toyota  White         150043      4   $4,000.00    4000.0     400000
# 1   honda    Red          87899      4   $5,000.00    5000.0     500000
# 2  toyota   Blue          32549      3   $7,000.00    7000.0     700000
# 3     bmw  Black          11179      5  $22,000.00   22000.0    2200000
# 4  nissan  White         213095      4   $3,500.00    3500.0     350000
# 5  toyota  Green          99213      4   $4,500.00    4500.0     450000
# 6   honda   Blue          45698      4   $7,500.00    7500.0     750000
# 7   honda   Blue          54738      4   $7,000.00    7000.0     700000
# 8  toyota  White          60000      4   $6,250.00    6250.0     625000
# 9  nissan  White          31600      4   $9,700.00    9700.0     970000

# %%
car_sales['Make'] = car_sales['Make'].str.capitalize()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice  NewPrice2
# 0  Toyota  White         150043      4   $4,000.00    4000.0     400000
# 1   Honda    Red          87899      4   $5,000.00    5000.0     500000
# 2  Toyota   Blue          32549      3   $7,000.00    7000.0     700000
# 3     Bmw  Black          11179      5  $22,000.00   22000.0    2200000
# 4  Nissan  White         213095      4   $3,500.00    3500.0     350000
# 5  Toyota  Green          99213      4   $4,500.00    4500.0     450000
# 6   Honda   Blue          45698      4   $7,500.00    7500.0     750000
# 7   Honda   Blue          54738      4   $7,000.00    7000.0     700000
# 8  Toyota  White          60000      4   $6,250.00    6250.0     625000
# 9  Nissan  White          31600      4   $9,700.00    9700.0     970000

# %% [markdown]
# ## Handling missing data

# %%
car_sales_missing  = pd.read_csv('car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Make      9 non-null      object
#  1   Colour    9 non-null      object
#  2   Odometer  6 non-null      float64
#  3   Doors     9 non-null      float64
#  4   Price     8 non-null      object
# dtypes: float64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales_missing['Odometer'].mean()
# Out:
# 92302.66666666667

# %%
car_sales_missing['Odometer'] = car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# ### fill na or missing values

# %%
#same as reassignment code car_sales_missing['Odometer'] = car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean())

car_sales_missing['Odometer'].fillna(car_sales_missing['Odometer'].mean(), inplace = True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# ### Dropping Na Value

# %%
car_sales_missing.dropna(inplace = True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv('car-sales-missing-data.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv('car-sales-missing-dropped.csv')

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_without_inplace_dropped = car_sales_missing.dropna()
car_sales_missing_without_inplace_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %% [markdown]
# ### creating data from existing values

# %%
# create columns from series
seats_columns = pd.Series([5,5,5,5,5])

#new column called "Seat"
car_sales['Seat'] = seats_columns

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice  NewPrice2  Seat
# 0  Toyota  White         150043      4   $4,000.00    4000.0     400000   5.0
# 1   Honda    Red          87899      4   $5,000.00    5000.0     500000   5.0
# 2  Toyota   Blue          32549      3   $7,000.00    7000.0     700000   5.0
# 3     Bmw  Black          11179      5  $22,000.00   22000.0    2200000   5.0
# 4  Nissan  White         213095      4   $3,500.00    3500.0     350000   5.0
# 5  Toyota  Green          99213      4   $4,500.00    4500.0     450000   NaN
# 6   Honda   Blue          45698      4   $7,500.00    7500.0     750000   NaN
# 7   Honda   Blue          54738      4   $7,000.00    7000.0     700000   NaN
# 8  Toyota  White          60000      4   $6,250.00    6250.0     625000   NaN
# 9  Nissan  White          31600      4   $9,700.00    9700.0     970000   NaN

# %%
car_sales.fillna(5, inplace = True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice  NewPrice2  Seat
# 0  Toyota  White         150043      4   $4,000.00    4000.0     400000   5.0
# 1   Honda    Red          87899      4   $5,000.00    5000.0     500000   5.0
# 2  Toyota   Blue          32549      3   $7,000.00    7000.0     700000   5.0
# 3     Bmw  Black          11179      5  $22,000.00   22000.0    2200000   5.0
# 4  Nissan  White         213095      4   $3,500.00    3500.0     350000   5.0
# 5  Toyota  Green          99213      4   $4,500.00    4500.0     450000   5.0
# 6   Honda   Blue          45698      4   $7,500.00    7500.0     750000   5.0
# 7   Honda   Blue          54738      4   $7,000.00    7000.0     700000   5.0
# 8  Toyota  White          60000      4   $6,250.00    6250.0     625000   5.0
# 9  Nissan  White          31600      4   $9,700.00    9700.0     970000   5.0

# %%
# create columns from python list
fuel_economy = [4.0, 5.1, 3.2, 5.2, 2.1, 9.1, 1.6, 7.8, 8.1, 4.3]
car_sales['Fuel per 100KM'] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice  NewPrice2  Seat  \
# 0  Toyota  White         150043      4   $4,000.00    4000.0     400000   5.0
# 1   Honda    Red          87899      4   $5,000.00    5000.0     500000   5.0
# 2  Toyota   Blue          32549      3   $7,000.00    7000.0     700000   5.0
# 3     Bmw  Black          11179      5  $22,000.00   22000.0    2200000   5.0
# 4  Nissan  White         213095      4   $3,500.00    3500.0     350000   5.0
# 5  Toyota  Green          99213      4   $4,500.00    4500.0     450000   5.0
# 6   Honda   Blue          45698      4   $7,500.00    7500.0     750000   5.0
# 7   Honda   Blue          54738      4   $7,000.00    7000.0     700000   5.0
# 8  Toyota  White          60000      4   $6,250.00    6250.0     625000   5.0
# 9  Nissan  White          31600      4   $9,700.00    9700.0     970000   5.0
#
#    Fuel per 100KM
# 0             4.0
# 1             5.1
# 2             3.2
# 3             5.2
# ...

# %%
car_sales['Total Fuel Used'] = car_sales['Odometer (KM)'] / 100 * car_sales['Fuel per 100KM']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice  NewPrice2  Seat  \
# 0  Toyota  White         150043      4   $4,000.00    4000.0     400000   5.0
# 1   Honda    Red          87899      4   $5,000.00    5000.0     500000   5.0
# 2  Toyota   Blue          32549      3   $7,000.00    7000.0     700000   5.0
# 3     Bmw  Black          11179      5  $22,000.00   22000.0    2200000   5.0
# 4  Nissan  White         213095      4   $3,500.00    3500.0     350000   5.0
# 5  Toyota  Green          99213      4   $4,500.00    4500.0     450000   5.0
# 6   Honda   Blue          45698      4   $7,500.00    7500.0     750000   5.0
# 7   Honda   Blue          54738      4   $7,000.00    7000.0     700000   5.0
# 8  Toyota  White          60000      4   $6,250.00    6250.0     625000   5.0
# 9  Nissan  White          31600      4   $9,700.00    9700.0     970000   5.0
#
#    Fuel per 100KM  Total Fuel Used
# 0             4.0         6001.720
# 1             5.1         4482.849
# ...

# %%
# create a column from single value
car_sales['Number of whells'] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice  NewPrice2  Seat  \
# 0  Toyota  White         150043      4   $4,000.00    4000.0     400000   5.0
# 1   Honda    Red          87899      4   $5,000.00    5000.0     500000   5.0
# 2  Toyota   Blue          32549      3   $7,000.00    7000.0     700000   5.0
# 3     Bmw  Black          11179      5  $22,000.00   22000.0    2200000   5.0
# 4  Nissan  White         213095      4   $3,500.00    3500.0     350000   5.0
# 5  Toyota  Green          99213      4   $4,500.00    4500.0     450000   5.0
# 6   Honda   Blue          45698      4   $7,500.00    7500.0     750000   5.0
# 7   Honda   Blue          54738      4   $7,000.00    7000.0     700000   5.0
# 8  Toyota  White          60000      4   $6,250.00    6250.0     625000   5.0
# 9  Nissan  White          31600      4   $9,700.00    9700.0     970000   5.0
#
#    Fuel per 100KM  Total Fuel Used  Number of whells
# 0             4.0         6001.720                 4
# ...

# %%
car_sales['Passed Road Safety'] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice  NewPrice2  Seat  \
# 0  Toyota  White         150043      4   $4,000.00    4000.0     400000   5.0
# 1   Honda    Red          87899      4   $5,000.00    5000.0     500000   5.0
# 2  Toyota   Blue          32549      3   $7,000.00    7000.0     700000   5.0
# 3     Bmw  Black          11179      5  $22,000.00   22000.0    2200000   5.0
# 4  Nissan  White         213095      4   $3,500.00    3500.0     350000   5.0
# 5  Toyota  Green          99213      4   $4,500.00    4500.0     450000   5.0
# 6   Honda   Blue          45698      4   $7,500.00    7500.0     750000   5.0
# 7   Honda   Blue          54738      4   $7,000.00    7000.0     700000   5.0
# 8  Toyota  White          60000      4   $6,250.00    6250.0     625000   5.0
# 9  Nissan  White          31600      4   $9,700.00    9700.0     970000   5.0
#
#    Fuel per 100KM  Number of whells  Passed Road Safety  Total fuel used (L)
# ...

# %% [markdown]
# ### deleting or dropping columns

# %%
del car_sales['Number of whells']

car_sales['Number of wheels'] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice  NewPrice2  Seat  \
# 0  Toyota  White         150043      4   $4,000.00    4000.0     400000   5.0
# 1   Honda    Red          87899      4   $5,000.00    5000.0     500000   5.0
# 2  Toyota   Blue          32549      3   $7,000.00    7000.0     700000   5.0
# 3     Bmw  Black          11179      5  $22,000.00   22000.0    2200000   5.0
# 4  Nissan  White         213095      4   $3,500.00    3500.0     350000   5.0
# 5  Toyota  Green          99213      4   $4,500.00    4500.0     450000   5.0
# 6   Honda   Blue          45698      4   $7,500.00    7500.0     750000   5.0
# 7   Honda   Blue          54738      4   $7,000.00    7000.0     700000   5.0
# 8  Toyota  White          60000      4   $6,250.00    6250.0     625000   5.0
# 9  Nissan  White          31600      4   $9,700.00    9700.0     970000   5.0
#
#    Fuel per 100KM  Passed Road Safety  Total fuel used (L)  Number of wheels
# ...

# %%
car_sales.drop('Total Fuel Used', axis = 1, inplace=True)

# %%
car_sales['Total fuel used (L)'] = car_sales['Odometer (KM)'] / 100 * car_sales['Fuel per 100KM']

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  NewPrice  NewPrice2  Seat  \
# 0  Toyota  White         150043      4   $4,000.00    4000.0     400000   5.0
# 1   Honda    Red          87899      4   $5,000.00    5000.0     500000   5.0
# 2  Toyota   Blue          32549      3   $7,000.00    7000.0     700000   5.0
# 3     Bmw  Black          11179      5  $22,000.00   22000.0    2200000   5.0
# 4  Nissan  White         213095      4   $3,500.00    3500.0     350000   5.0
# 5  Toyota  Green          99213      4   $4,500.00    4500.0     450000   5.0
# 6   Honda   Blue          45698      4   $7,500.00    7500.0     750000   5.0
# 7   Honda   Blue          54738      4   $7,000.00    7000.0     700000   5.0
# 8  Toyota  White          60000      4   $6,250.00    6250.0     625000   5.0
# 9  Nissan  White          31600      4   $9,700.00    9700.0     970000   5.0
#
#    Fuel per 100KM  Passed Road Safety  Total fuel used (L)  Number of wheels
# ...
