# %%
import pandas as pd

# %%
data = pd.read_csv("Data/artwork_data.csv", low_memory = False)

# %%
data.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69201 entries, 0 to 69200
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  69201 non-null  int64
#  1   accession_number    69201 non-null  object
#  2   artist              69201 non-null  object
#  3   artistRole          69201 non-null  object
#  4   artistId            69201 non-null  int64
#  5   title               69201 non-null  object
#  6   dateText            69201 non-null  object
#  7   medium              62817 non-null  object
#  8   creditLine          69198 non-null  object
#  9   year                63823 non-null  object
#  10  acquisitionYear     69156 non-null  float64
#  11  dimensions          66768 non-null  object
#  12  width               65860 non-null  object
#  13  height              65860 non-null  object
#  14  depth               2514 non-null   float64
# ...

# %% [markdown]
# # 1) Stripping White Space

# %% [markdown]
# ### check white space in `title` column

# %%
data.loc[data.title.str.contains("\s$", regex = True)]
# Out:
#           id accession_number                artist artistRole  artistId  \
# 49498   4308           P07466  Hamilton Finlay, Ian     artist      1093
# 50534   2235           P11065         Clarke, Brian     artist       911
# 50535   2236           P11066         Clarke, Brian     artist       911
# 50537   2238           P11068         Clarke, Brian     artist       911
# 53186  21168           P77679     Bourgeois, Louise     artist      2351
# 56283   5826           T00705     Hamilton, Richard     artist      1244
# 67409  88191           T12064          Leach, David     artist      7651
# 67432  88215           T12087        Leach, Bernard     artist      1478
#
#                                                    title dateText  \
# 49498  Port-Distinguishing Letters of Scottish Fishin...     1976
# 50534                                              Boys      1981
# 50535                                         Buildings      1981
# ...

# %% [markdown]
# ## 1.1) white space stripping on entire column

# %%
data.title.str.strip()
# Out:
# 0        A Figure Bowing before a Seated Old Man with h...
# 1        Two Drawings of Frightened Figures, Probably f...
# 2        The Preaching of Warning. Verso: An Old Man En...
# 3           Six Drawings of Figures with Outstretched Arms
# 4        The Circle of the Lustful: Francesca da Rimini...
#                                ...
# 69196                          Larvae (from Tampax Romana)
# 69197                     Living Womb (from Tampax Romana)
# 69198                                        Present Tense
# 69199            Work No. 227: The lights going on and off
# 69200                     Dancing Scene in the West Indies
# Name: title, Length: 69201, dtype: object

# %%
data.title = data.title.str.strip()

# %%
# confirm again
# now there is no rows with whitespace in title
data.loc[data.title.str.contains("\s$", regex = True)]
# Out:
# Empty DataFrame
# Columns: [id, accession_number, artist, artistRole, artistId, title, dateText, medium, creditLine, year, acquisitionYear, dimensions, width, height, depth, units, inscription, thumbnailCopyright, thumbnailUrl, url]
# Index: []

# %% [markdown]
# ### other methods : `rstrip()` and `lstrip()`

# %% [markdown]
# ## 1.2) Alternative approach: using `transform()`
# - this method has more flexibility as we can do different operations using lambda

# %%
data.title.transform(lambda x : x.strip())
# Out:
# 0        A Figure Bowing before a Seated Old Man with h...
# 1        Two Drawings of Frightened Figures, Probably f...
# 2        The Preaching of Warning. Verso: An Old Man En...
# 3           Six Drawings of Figures with Outstretched Arms
# 4        The Circle of the Lustful: Francesca da Rimini...
#                                ...
# 69196                          Larvae (from Tampax Romana)
# 69197                     Living Womb (from Tampax Romana)
# 69198                                        Present Tense
# 69199            Work No. 227: The lights going on and off
# 69200                     Dancing Scene in the West Indies
# Name: title, Length: 69201, dtype: object

# %% [markdown]
# -----------------

# %% [markdown]
# # 2) Replacing Bad data with NaN

# %%
data = pd.read_csv("Data/artwork_data.csv", low_memory = False)

# %%
data.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %% [markdown]
# ## 2.1) replacing with NaN  using `replace` method, for `dateText` where `date not known`

# %% [markdown]
# ### first check the the entire column for na values

# %%
pd.isna(data.loc[:, "dateText"])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Name: dateText, Length: 69201, dtype: bool

# %% [markdown]
# ### replacing with nan

# %%
from numpy import nan

# %%
data.replace({'dataText' : {'date not known' : nan}}, inplace = True)

# %%
data.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %% [markdown]
# ## 2.2) replacing nan using `loc` method

# %%
data = pd.read_csv("Data/artwork_data.csv", low_memory = False)
data.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %%
data.loc[data.dateText == "date not known", ["dateText"]] = nan

# %%
data.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...      NaN
# 1  Two Drawings of Frightened Figures, Probably f...      NaN
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %% [markdown]
# ----------

# %% [markdown]
# ### check `year` data for bad data

# %%
# check year data which contains values but contains data other than digits too
data.loc[data.year.notnull() & data.year.str.contains("[^0-9]")]
# Out:
#            id accession_number            artist artistRole  artistId  \
# 67968   99332           T12629  Roberts, William     artist      1855
# 67980   99346           T12641  Roberts, William     artist      1855
# 67987   99354           T12648  Roberts, William     artist      1855
# 67994   99361           T12655  Roberts, William     artist      1855
# 68002   99370           T12663  Roberts, William     artist      1855
# 68015   99384           T12676  Roberts, William     artist      1855
# 68033   99407           T12694  Roberts, William     artist      1855
# 68042   99426           T12703  Roberts, William     artist      1855
# 68047   99431           T12708  Roberts, William     artist      1855
# 68051   99435           T12712  Roberts, William     artist      1855
# 68056   99440           T12717  Roberts, William     artist      1855
# 68057   99441           T12718  Roberts, William     artist      1855
# ...

# %%
data.loc[data.year.notnull() & data.year.astype(str).str.contains("[^0-9]"), ["year"]] = nan

# %%
data.head(2)
# Out:
#        id accession_number         artist artistRole  artistId  \
# 0  1035.0           A00001  Blake, Robert     artist      38.0
# 1  1036.0           A00002  Blake, Robert     artist      38.0
#
#                                                title dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...      NaN
# 1  Two Drawings of Frightened Figures, Probably f...      NaN
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %% [markdown]
# --------------

# %% [markdown]
# # 3) Filling missing data with a value

# %%
data = pd.read_csv("Data/artwork_data.csv", low_memory = False)

# %%
data.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %%
data.fillna(0)
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %% [markdown]
# now we can see fillna() with 0 has filled every nan values across with 0, but we only want `depth` column for now.

# %% [markdown]
# ## 3.1) fill nan value for specific column
# - df.fillna(value = {"col_name": value})

# %%
data.fillna(value = {"depth": 0})
# Out:
#            id accession_number              artist artistRole  artistId  \
# 0        1035           A00001       Blake, Robert     artist        38
# 1        1036           A00002       Blake, Robert     artist        38
# 2        1037           A00003       Blake, Robert     artist        38
# 3        1038           A00004       Blake, Robert     artist        38
# 4        1039           A00005      Blake, William     artist        39
# ...       ...              ...                 ...        ...       ...
# 69196  122960           T13865  P-Orridge, Genesis     artist     16646
# 69197  122961           T13866  P-Orridge, Genesis     artist     16646
# 69198  121181           T13867        Hatoum, Mona     artist      2365
# 69199  112306           T13868       Creed, Martin     artist      2760
# 69200  127035           T13869   Brunias, Agostino     artist      3824
#
#                                                    title  \
# ...

# %%
data.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %%
data.fillna(value = {"depth": 0}, inplace = True)

# %%
data.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    0.0    mm         NaN
# 1  support: 311 x 213 mm   311    213    0.0    mm         NaN
#
# ...

# %% [markdown]
# ----------

# %% [markdown]
# # 4) Dropping rows of data

# %%
data = pd.read_csv("Data/artwork_data.csv", low_memory = False)
data.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %%
data.shape
# Out:
# (69201, 20)

# %% [markdown]
# ### 4.1) drop nan values

# %%
data.dropna()
# Out:
#           id accession_number                 artist artistRole  artistId  \
# 1738   98171          AR00001             Katz, Alex     artist      1386
# 1739   98172          AR00002             Katz, Alex     artist      1386
# 1740   98173          AR00003             Katz, Alex     artist      1386
# 1741   98174          AR00004             Katz, Alex     artist      1386
# 1742   98175          AR00005             Katz, Alex     artist      1386
# ...      ...              ...                    ...        ...       ...
# 61878  20155           T06453      Buchheister, Carl     artist      2276
# 62083  20568           T06659          Gober, Robert     artist      2309
# 62274  20984           T06858  Paolozzi, Sir Eduardo     artist      1738
# 62466  21517           T07052          Irvin, Albert     artist      1342
# 62596  21805           T07183       Davey, Grenville     artist      2295
#
#                               title dateText  \
# ...

# %%
data.dropna().shape
# Out:
# (164, 20)

# %% [markdown]
# ### 4.2) dropping rows only if all values of all columns are null
# - useful at the final stage of data cleaning, after you converted all values to numerical

# %%
data.dropna(how = "all").shape
# Out:
# (69201, 20)

# %% [markdown]
# ### 4.3) dropping rows using `threshold`

# %%
# drop the row only if 15 of columns values are null (out of data frame's 20 columns)
data.dropna(thresh = 15). shape
# Out:
# (66379, 20)

# %% [markdown]
# ## 4.4) dropping rows based on specific column's values are NaN
# - or
# - and (using `how = all`)

# %%
#drop the rows only if year or acquisitionYear column values are NaN
data.dropna(subset = ["year", "acquisitionYear"]).shape
# Out:
# (63781, 20)

# %%
#drop the rows only if BOTH year and acquisitionYear column values are NaN
data.dropna(subset = ["year", "acquisitionYear"], how = "all").shape
# Out:
# (69198, 20)

# %%
data.dropna(subset = ["year", "acquisitionYear"], how = "all", inplace = True)

# %%
data.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %% [markdown]
# ----------------

# %% [markdown]
# # 5) Identifying and Dropping Duplicate Data

# %%
data = pd.read_csv("Data/artwork_sample.csv")

# %%
data.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine  year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922   NaN             1922
# 1  Presented by Mrs John Richmond 1922   NaN             1922
#
#               dimensions  width  height  depth units  inscription  \
# 0  support: 394 x 419 mm    394     419    NaN    mm          NaN
# 1  support: 311 x 213 mm    311     213    NaN    mm          NaN
#
# ...

# %% [markdown]
# ### 5.1) dropping duplicates based on specific column

# %%
# now we try to drop duplicates based on "artist" column
data.drop_duplicates(subset = ["artist"])
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 4                            Line engraving on paper
#
#                                           creditLine    year  acquisitionYear  \
# 0                Presented by Mrs John Richmond 1922     NaN             1922
# 4  Purchased with the assistance of a special gra...  1826.0             1919
#
#               dimensions  width  height  depth units  inscription  \
# 0  support: 394 x 419 mm    394     419    NaN    mm          NaN
# ...

# %% [markdown]
# now only two rows remains. This makes sense because there are only 2 distinct artist name.

# %% [markdown]
# ### 5.2) keep first and keep last

# %%
data.drop_duplicates(subset = ["artist"], keep = "first")
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 4                            Line engraving on paper
#
#                                           creditLine    year  acquisitionYear  \
# 0                Presented by Mrs John Richmond 1922     NaN             1922
# 4  Purchased with the assistance of a special gra...  1826.0             1919
#
#               dimensions  width  height  depth units  inscription  \
# 0  support: 394 x 419 mm    394     419    NaN    mm          NaN
# ...

# %%
data.drop_duplicates(subset = ["artist"], keep = "last")
# Out:
#      id accession_number          artist artistRole  artistId  \
# 3  1038           A00004   Blake, Robert     artist        38
# 9  1044           A00010  Blake, William     artist        39
#
#                                             title                dateText  \
# 3  Six Drawings of Figures with Outstretched Arms          date not known
# 9              The Pit of Disease: The Falsifiers  1826–7, reprinted 1892
#
#                     medium                                         creditLine  \
# 3        Graphite on paper                Presented by Mrs John Richmond 1922
# 9  Line engraving on paper  Purchased with the assistance of a special gra...
#
#      year  acquisitionYear             dimensions  width  height  depth units  \
# 3     NaN             1922  support: 318 x 394 mm    318     394    NaN    mm
# 9  1826.0             1919    image: 243 x 340 mm    243     340    NaN    mm
#
#    inscription  thumbnailCopyright  \
# 3          NaN                 NaN
# ...

# %% [markdown]
# ### 5.3) keep none if there is more than one duplicate for that value

# %%
data.drop_duplicates(subset = ["artist"], keep = False)
# this returns none because each of the artist has more than one rows
# Out:
# Empty DataFrame
# Columns: [id, accession_number, artist, artistRole, artistId, title, dateText, medium, creditLine, year, acquisitionYear, dimensions, width, height, depth, units, inscription, thumbnailCopyright, thumbnailUrl, url]
# Index: []

# %% [markdown]
# -------

# %%
data.drop_duplicates(subset = ["artist"], keep = "first")
# Out:
#      id accession_number          artist artistRole  artistId  \
# 0  1035           A00001   Blake, Robert     artist        38
# 4  1039           A00005  Blake, William     artist        39
#
#                                                title                dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...          date not known
# 4  The Circle of the Lustful: Francesca da Rimini...  1826–7, reprinted 1892
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 4                            Line engraving on paper
#
#                                           creditLine    year  acquisitionYear  \
# 0                Presented by Mrs John Richmond 1922     NaN             1922
# 4  Purchased with the assistance of a special gra...  1826.0             1919
#
#               dimensions  width  height  depth units  inscription  \
# 0  support: 394 x 419 mm    394     419    NaN    mm          NaN
# ...

# %% [markdown]
# -----------------

# %%
data = pd.read_csv("Data/artwork_data.csv", low_memory = False)
data.head(2)
# Out:
#      id accession_number         artist artistRole  artistId  \
# 0  1035           A00001  Blake, Robert     artist        38
# 1  1036           A00002  Blake, Robert     artist        38
#
#                                                title        dateText  \
# 0  A Figure Bowing before a Seated Old Man with h...  date not known
# 1  Two Drawings of Frightened Figures, Probably f...  date not known
#
#                                               medium  \
# 0  Watercolour, ink, chalk and graphite on paper....
# 1                                  Graphite on paper
#
#                             creditLine year  acquisitionYear  \
# 0  Presented by Mrs John Richmond 1922  NaN           1922.0
# 1  Presented by Mrs John Richmond 1922  NaN           1922.0
#
#               dimensions width height  depth units inscription  \
# 0  support: 394 x 419 mm   394    419    NaN    mm         NaN
# 1  support: 311 x 213 mm   311    213    NaN    mm         NaN
#
# ...

# %%
data.shape
# Out:
# (69201, 20)

# %% [markdown]
# ## 5.5) checking which rows are duplicated

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Length: 69201, dtype: bool

# %%
data.loc[data.duplicated()]
# returns nothing because none of the rows are fully duplicated
# Out:
# Empty DataFrame
# Columns: [id, accession_number, artist, artistRole, artistId, title, dateText, medium, creditLine, year, acquisitionYear, dimensions, width, height, depth, units, inscription, thumbnailCopyright, thumbnailUrl, url]
# Index: []

# %%
# we set keep=False, because we want to IDENTIFY the duplicates on every rows (we don't want to exclude the first or last or keep it for now)
# otherwise duplicated() method will return false on each of those rows and this won't help much us to identify the duplicates.
data.duplicated(subset = ["artist", "title"], keep = False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 69196    False
# 69197    False
# 69198    False
# 69199    False
# 69200    False
# Length: 69201, dtype: bool

# %%
data.loc[data.duplicated(subset = ["artist", "title"], keep = False)]
# Out:
#            id accession_number            artist artistRole  artistId  \
# 4        1039           A00005    Blake, William     artist        39
# 5        1040           A00006    Blake, William     artist        39
# 6        1041           A00007    Blake, William     artist        39
# 7        1042           A00008    Blake, William     artist        39
# 8        1043           A00009    Blake, William     artist        39
# ...       ...              ...               ...        ...       ...
# 69169  121194           T13838  Barlow, Phyllida     artist     10908
# 69170  121195           T13839  Barlow, Phyllida     artist     10908
# 69171  121196           T13840  Barlow, Phyllida     artist     10908
# 69172  121197           T13841  Barlow, Phyllida     artist     10908
# 69173  121198           T13842  Barlow, Phyllida     artist     10908
#
#                                                    title  \
# 4      The Circle of the Lustful: Francesca da Rimini...
# ...

# %% [markdown]
# ### let's dig more details what are causing the above data as duplicates

# %%
data.loc[data.title.str.contains("The Circle of the Lustful")]
# as we can see the following as not really duplicate because if we can dateText, one is reprinted in 1892 and other is in 1968
# so it's up to us now how want want to handle those cases
# Out:
#          id accession_number          artist artistRole  artistId  \
# 4      1039           A00005  Blake, William     artist        39
# 57394  1156           T01950  Blake, William     artist        39
#
#                                                    title  \
# 4      The Circle of the Lustful: Francesca da Rimini...
# 57394  The Circle of the Lustful: Francesca da Rimini...
#
#                      dateText                   medium  \
# 4      1826–7, reprinted 1892  Line engraving on paper
# 57394  1826–7, reprinted 1968  Line-engraving on paper
#
#                                               creditLine  year  \
# 4      Purchased with the assistance of a special gra...  1826
# 57394             Presented by Lessing J. Rosenwald 1975  1826
#
#        acquisitionYear           dimensions width height  depth units  \
# 4               1919.0  image: 243 x 335 mm   243    335    NaN    mm
# 57394           1975.0  image: 243 x 335 mm   243    335    NaN    mm
#
# ...
