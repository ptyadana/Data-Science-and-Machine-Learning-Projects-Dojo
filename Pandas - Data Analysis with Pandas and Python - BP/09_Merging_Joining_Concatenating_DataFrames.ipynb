# %% [markdown]
# # 1) Intro to Merging, Joining and Concatenating DataFrames

# %%
import pandas as pd

# %%
week1 = pd.read_csv('Data/Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Data/Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Data/Restaurant - Customers.csv')
foods = pd.read_csv('Data/Restaurant - Foods.csv')

# %% [markdown]
# -------

# %% [markdown]
# # 2) The `pd.concat` Method, Part 1

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %% [markdown]
# ## Preserving Original Index after concat
#
# We can easily combine week1 and week2 as columns are the same.
#
# There are a total of 500 rows. But if we look a the index, we can see 249. This is because pandas glue one dataframe on top of each other without modifying the index. Note that in Pandas there can be same index, no need to be unique.
# ### If we need to preserve original index we need to set `ignore_index=False`, This will retain the original index after concatenation.

# %%
pd.concat(objs=[week1, week2])
pd.concat(objs=[week1, week2], ignore_index=False)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 245          783       10
# 246          556       10
# 247          547        9
# 248          252        9
# 249          249        6
#
# [500 rows x 2 columns]

# %% [markdown]
# ### Otherwise, we can put `ignore_index=True`
#
# We can see that the brand new indexes are created after concat.

# %%
pd.concat(objs=[week1, week2], ignore_index=True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 495          783       10
# 496          556       10
# 497          547        9
# 498          252        9
# 499          249        6
#
# [500 rows x 2 columns]

# %% [markdown]
# # Alternative method is `append()`

# %%
week1.append(other=week2)
week1.append(other=week2, ignore_index=False)

week1.append(other=week2, ignore_index=True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 495          783       10
# 496          556       10
# 497          547        9
# 498          252        9
# 499          249        6
#
# [500 rows x 2 columns]

# %% [markdown]
# -------

# %% [markdown]
# # 3) The `pd.concat()` Method, Part 2

# %%
week1 = pd.read_csv('Data/Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Data/Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Data/Restaurant - Customers.csv')
foods = pd.read_csv('Data/Restaurant - Foods.csv')

# %% [markdown]
# ##  What if we want the best of both world?
# + Create Brand New indexes
# + also Retain the Original Indexes
#
# ### The answer is `Multi Index`

# %% [markdown]
# ## `Keys` parameter
# + represents unique key identifier attached to each dataframe
#
# Now we have unique identifier for each row, also retaining the original index.

# %%
sales = pd.concat(objs=[week1, week2], keys=['Week1', 'Week2'])
sales.head(3)
# Out:
#          Customer ID  Food ID
# Week1 0          537        9
#       1           97        4
#       2          658        1

# %% [markdown]
# Now we can use our good old trusty `.loc` to extract information.

# %%
sales.loc[('Week1',)]

sales.loc[('Week1', 0)]
sales.loc['Week2', 50]

sales.loc[('Week1', 240), 'Customer ID']
sales.loc[('Week2', 183), ['Customer ID', 'Food ID']]
# Out:
# Customer ID    858
# Food ID          5
# Name: (Week2, 183), dtype: int64

# %% [markdown]
# -----

# %% [markdown]
# # 4) Inner Joins, Part 1

# %%
week1 = pd.read_csv('Data/Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Data/Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Data/Restaurant - Customers.csv')
foods = pd.read_csv('Data/Restaurant - Foods.csv')

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %% [markdown]
# ### `on` needs to be on same name key

# %%
week1.merge(week2, how='inner', on='Customer ID').head()
# Out:
#    Customer ID  Food ID_x  Food ID_y
# 0          537          9          5
# 1          155          9          3
# 2          155          1          3
# 3          503          5          8
# 4          503          5          9

# %% [markdown]
# We can see that Food ID is suffixed with x and y indicating Week1 and week2 tables.
#
# There are also Customers who appear more than twice. We can dig into this.
#
# Example: for customer ID 155, he came to in week1 two times and ordered different food items.
#
# **There will be no de-dup.**
#
# **Pandas will just combine every possible combinations.**

# %%
week1[week1['Customer ID'] == 155]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
week2[week2['Customer ID'] == 155]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %% [markdown]
# ## We can customize `suffixes` too

# %%
week1.merge(week2, how='inner', on='Customer ID', suffixes=['Week - 1', 'Week - 2'])
# Out:
#     Customer ID  Food IDWeek - 1  Food IDWeek - 2
# 0           537                9                5
# 1           155                9                3
# 2           155                1                3
# 3           503                5                8
# 4           503                5                9
# ..          ...              ...              ...
# 57          945                5                4
# 58          343                3                5
# 59          343                3                2
# 60          343                3                7
# 61          621                9                6
#
# [62 rows x 3 columns]

# %% [markdown]
# ------

# %% [markdown]
# # 5) Inner Joins, Part 2

# %%
week1 = pd.read_csv('Data/Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Data/Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Data/Restaurant - Customers.csv')
foods = pd.read_csv('Data/Restaurant - Foods.csv')

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %% [markdown]
# ### Who are the customers who ordered the same food Item in both week1 and week2?

# %%
week1.merge(week2, how='inner', on=['Customer ID', 'Food ID'])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
week1[week1['Customer ID'] == 21]
# Out:
#      Customer ID  Food ID
# 101           21        4
# 212           21        4

# %%
week2[week2['Customer ID'] == 21]
# Out:
#     Customer ID  Food ID
# 30           21        4

# %% [markdown]
# ------

# %% [markdown]
# # 6) Outer Joins

# %%
week1 = pd.read_csv('Data/Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Data/Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Data/Restaurant - Customers.csv')
foods = pd.read_csv('Data/Restaurant - Foods.csv')

# %%
week1.head(2)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4

# %%
week2.head(2)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7

# %%
week1.merge(week2, how='outer', on='Customer ID', suffixes=[' - Week1', ' - Week2'])
# Out:
#      Customer ID  Food ID - Week1  Food ID - Week2
# 0            537              9.0              5.0
# 1             97              4.0              NaN
# 2            658              1.0              NaN
# 3            202              2.0              NaN
# 4            155              9.0              3.0
# ..           ...              ...              ...
# 449          855              NaN              4.0
# 450          559              NaN             10.0
# 451          276              NaN              4.0
# 452          556              NaN             10.0
# 453          252              NaN              9.0
#
# [454 rows x 3 columns]

# %%
len(week1.merge(week2, how='outer', on='Customer ID', suffixes=[' - Week1', ' - Week2']))
# Out:
# 454

# %% [markdown]
# ## `indicator` : tells visually where data are pulled from
# + we can see which table, data were pulled from

# %%
merged = week1.merge(week2, how='outer', on='Customer ID', suffixes=[' - Week1', ' - Week2'], 
                   indicator=True)

merged
# Out:
#      Customer ID  Food ID - Week1  Food ID - Week2      _merge
# 0            537              9.0              5.0        both
# 1             97              4.0              NaN   left_only
# 2            658              1.0              NaN   left_only
# 3            202              2.0              NaN   left_only
# 4            155              9.0              3.0        both
# ..           ...              ...              ...         ...
# 449          855              NaN              4.0  right_only
# 450          559              NaN             10.0  right_only
# 451          276              NaN              4.0  right_only
# 452          556              NaN             10.0  right_only
# 453          252              NaN              9.0  right_only
#
# [454 rows x 4 columns]

# %%
merged['_merge'].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %% [markdown]
# We can see 197 unique customers in Week2, 195 unique customers in Week 1 and 62 common customers in both Week1 and Week2.

# %%
197 + 195 + 62
# Out:
# 454

# %% [markdown]
# ## Let's say we want to find out customers who visited to Restrurant in either Week1 and Week2, not in both weeks.

# %%
mask = merged['_merge'] != 'both'
merged[mask]

mask = merged['_merge'].isin(['left_only', 'right_only'])
merged[mask]
# Out:
#      Customer ID  Food ID - Week1  Food ID - Week2      _merge
# 1             97              4.0              NaN   left_only
# 2            658              1.0              NaN   left_only
# 3            202              2.0              NaN   left_only
# 6            213              8.0              NaN   left_only
# 7            600              1.0              NaN   left_only
# ..           ...              ...              ...         ...
# 449          855              NaN              4.0  right_only
# 450          559              NaN             10.0  right_only
# 451          276              NaN              4.0  right_only
# 452          556              NaN             10.0  right_only
# 453          252              NaN              9.0  right_only
#
# [392 rows x 4 columns]

# %% [markdown]
# ---

# %% [markdown]
# # 7) Left Joins / Right Joins

# %%
week1 = pd.read_csv('Data/Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Data/Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Data/Restaurant - Customers.csv')
foods = pd.read_csv('Data/Restaurant - Foods.csv')

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
foods.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %% [markdown]
# ### Which foods does customer order?

# %%
week1.merge(foods, how='left', on='Food ID')
# Out:
#      Customer ID  Food ID   Food Item  Price
# 0            537        9       Donut   0.99
# 1             97        4  Quesadilla   4.25
# 2            658        1       Sushi   3.99
# 3            202        2     Burrito   9.99
# 4            155        9       Donut   0.99
# ..           ...      ...         ...    ...
# 245          413        9       Donut   0.99
# 246          926        6       Pasta  13.99
# 247          134        3        Taco   2.99
# 248          396        6       Pasta  13.99
# 249          535       10       Drink   1.75
#
# [250 rows x 4 columns]

# %% [markdown]
# ## `sort` parameter

# %%
week1.merge(foods, how='left', on='Food ID', sort=True)
# Out:
#      Customer ID  Food ID Food Item  Price
# 0            658        1     Sushi   3.99
# 1            600        1     Sushi   3.99
# 2            155        1     Sushi   3.99
# 3            341        1     Sushi   3.99
# 4             20        1     Sushi   3.99
# ..           ...      ...       ...    ...
# 245          809       10     Drink   1.75
# 246          584       10     Drink   1.75
# 247          274       10     Drink   1.75
# 248          151       10     Drink   1.75
# 249          535       10     Drink   1.75
#
# [250 rows x 4 columns]

# %%
week1.merge(week2, how='right', on='Customer ID', suffixes=[' - Week1', ' - Week2'], indicator=True)
# Out:
#      Customer ID  Food ID - Week1  Food ID - Week2      _merge
# 0            688              NaN               10  right_only
# 1            813              NaN                7  right_only
# 2            495              NaN               10  right_only
# 3            495              NaN                6  right_only
# 4            495              NaN                2  right_only
# ..           ...              ...              ...         ...
# 254          945              5.0                4        both
# 255          783              6.0               10        both
# 256          556              NaN               10  right_only
# 257          252              NaN                9  right_only
# 258          249              9.0                6        both
#
# [259 rows x 4 columns]

# %% [markdown]
# -------

# %% [markdown]
# # 8) The `left_on` and `right_on` Parameters
# + usually use them when we have different Keys in left and right tables.

# %%
week1 = pd.read_csv('Data/Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Data/Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Data/Restaurant - Customers.csv')
foods = pd.read_csv('Data/Restaurant - Foods.csv')

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %% [markdown]
# ### If we have Keys with different name in tables

# %%
week2.merge(customers, how='left', left_on='Customer ID', right_on='ID').head(2)
# Out:
#    Customer ID  Food ID   ID First Name   Last Name Gender     Company  \
# 0          688       10  688       Carl  Williamson   Male  Thoughtmix
# 1          813        7  813     Johnny      Walker   Male      Kayveo
#
#          Occupation
# 0  Graphic Designer
# 1      Developer II

# %% [markdown]
# After merging, we can see that both 'Customer ID' and 'ID' are presented. **As those information are duplicated, we can drop one of them.**

# %%
week2.merge(customers, how='left', left_on='Customer ID', right_on='ID').drop('ID', axis=1)

week2 = week2.merge(customers, how='left', left_on='Customer ID', right_on='ID', sort=True).drop('ID', axis=1)
week2
# Out:
#      Customer ID  Food ID First Name Last Name  Gender        Company  \
# 0              8        6    Frances     Adams  Female       Dabshots
# 1             13        2       Ruth   Alvarez  Female    Twitterlist
# 2             21        4     Albert     Burns    Male      Rhynoodle
# 3             24        8      Donna    Thomas  Female        Jaxbean
# 4             27        4    Jessica   Bennett  Female  Twitternation
# ..           ...      ...        ...       ...     ...            ...
# 245          968        4     Teresa  Reynolds  Female       Flashdog
# 246          969        3      Marie     Ortiz  Female          Meejo
# 247          977        7    Cynthia     Dixon  Female        Skalith
# 248          994        2   Clarence    Morgan    Male       Edgewire
# 249          996       10      Debra    Garcia  Female   Dazzlesphere
#
#                        Occupation
# 0                   Developer III
# 1     Mechanical Systems Engineer
# 2                Junior Executive
# 3           Chief Design Engineer
# 4               Account Executive
# ..                            ...
# 245  Budget/Accounting Analyst IV
# 246            Research Associate
# 247      Automation Specialist II
# 248                  Geologist II
# 249           Structural Engineer
#
# [250 rows x 7 columns]

# %% [markdown]
# -------

# %% [markdown]
# # 9) Merging by Indexes with the `left_index` and `right_index` Parameters
# + Sometimes we want to use column indexes to merge. Then we can use those parameters.

# %%
week1 = pd.read_csv('Data/Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Data/Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Data/Restaurant - Customers.csv', index_col=['ID'])
foods = pd.read_csv('Data/Restaurant - Foods.csv', index_col=['Food ID'])

# %%
customers.head(3)
# Out:
#    First Name Last Name  Gender  Company                     Occupation
# ID
# 1      Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 2    Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 3       Roger     Black    Male  Tagfeed              Account Executive

# %%
foods.head(3)
# Out:
#         Food Item  Price
# Food ID
# 1           Sushi   3.99
# 2         Burrito   9.99
# 3            Taco   2.99

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %% [markdown]
# ### We want to merge Week1 and Customers Table. However in Customer table, there is no Customer ID column. Instead it is index.
#
# + We can use `right_index=True` to tell pandas that we want to use right index for merging
# + one advantage is no additional column is created (example: ID column that we needed to drop previously.)

# %%
sales = week1.merge(customers, how='left', left_on='Customer ID', right_index=True)
sales.head(3)
# Out:
#    Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0          537        9     Cheryl   Carroll  Female   Zoombeat
# 1           97        4     Amanda   Watkins  Female        Ozu
# 2          658        1    Patrick      Webb    Male  Browsebug
#
#                       Occupation
# 0               Registered Nurse
# 1            Account Coordinator
# 2  Community Outreach Specialist

# %%
# merge with Foods df
sales = sales.merge(foods, how='left', left_on='Food ID', right_index=True)
sales.head(3)
# Out:
#    Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0          537        9     Cheryl   Carroll  Female   Zoombeat
# 1           97        4     Amanda   Watkins  Female        Ozu
# 2          658        1    Patrick      Webb    Male  Browsebug
#
#                       Occupation   Food Item  Price
# 0               Registered Nurse       Donut   0.99
# 1            Account Coordinator  Quesadilla   4.25
# 2  Community Outreach Specialist       Sushi   3.99

# %% [markdown]
# ## We want to see the sequences of Customers purchasing

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
week1.merge(week2, how='left', left_index=True, right_index=True, suffixes=[' - Week 1', ' - Week 2'])

# We can see which customers made first purchases in week 1 and week 2, second purchase, third purchase, etc.
# Out:
#      Customer ID - Week 1  Food ID - Week 1  Customer ID - Week 2  \
# 0                     537                 9                   688
# 1                      97                 4                   813
# 2                     658                 1                   495
# 3                     202                 2                   189
# 4                     155                 9                   267
# ..                    ...               ...                   ...
# 245                   413                 9                   783
# 246                   926                 6                   556
# 247                   134                 3                   547
# 248                   396                 6                   252
# 249                   535                10                   249
#
#      Food ID - Week 2
# 0                  10
# 1                   7
# 2                  10
# 3                   5
# 4                   3
# ..                ...
# 245                10
# 246                10
# 247                 9
# 248                 9
# 249                 6
#
# [250 rows x 4 columns]

# %% [markdown]
# -----

# %% [markdown]
# # 10) The `.join()` Method

# %%
week1 = pd.read_csv('Data/Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Data/Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Data/Restaurant - Customers.csv')
foods = pd.read_csv('Data/Restaurant - Foods.csv')
satisfication = pd.read_csv('Data/Restaurant - Week 1 Satisfaction.csv')

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
satisfication.head(3)
# Out:
#    Satisfaction Rating
# 0                    2
# 1                    7
# 2                    3

# %%
week1.merge(satisfication, how='left', left_index=True, right_index=True).head(3)
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3

# %% [markdown]
# ### We can get the same result by using join.
# + join will merge using indexes of both tables.
# + However, merge method is more versitile.

# %%
week1.join(satisfication).head(3)
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3

# %% [markdown]
# -----

# %% [markdown]
# # 11) The `pd.merge()` Method

# %%
week1 = pd.read_csv('Data/Restaurant - Week 1 Sales.csv')
week2 = pd.read_csv('Data/Restaurant - Week 2 Sales.csv')
customers = pd.read_csv('Data/Restaurant - Customers.csv')
foods = pd.read_csv('Data/Restaurant - Foods.csv')
satisfication = pd.read_csv('Data/Restaurant - Week 1 Satisfaction.csv')

# %% [markdown]
# It is basically the same like directly using DataFrame. The only difference is to tell which is `left` and `right` dataframes.

# %%
pd.merge(left=week1, right=customers, how='left', left_on='Customer ID', right_on = 'ID')
# Out:
#      Customer ID  Food ID   ID First Name Last Name  Gender    Company  \
# 0            537        9  537     Cheryl   Carroll  Female   Zoombeat
# 1             97        4   97     Amanda   Watkins  Female        Ozu
# 2            658        1  658    Patrick      Webb    Male  Browsebug
# 3            202        2  202      Louis  Campbell    Male  Rhynoodle
# 4            155        9  155    Carolyn      Diaz  Female   Gigazoom
# ..           ...      ...  ...        ...       ...     ...        ...
# 245          413        9  413      Diane    Bailey  Female    Wikibox
# 246          926        6  926       Anne    Wagner  Female      Skyba
# 247          134        3  134      Diana      Hall  Female      Quinu
# 248          396        6  396       Juan    Romero    Male    Zoonder
# 249          535       10  535      Nancy       Cox  Female     Trudeo
#
#                         Occupation
# 0                 Registered Nurse
# 1              Account Coordinator
# 2    Community Outreach Specialist
# 3       Account Representative III
# 4       Database Administrator III
# ..                             ...
# 245               Technical Writer
# 246                Legal Assistant
# 247              Financial Advisor
# 248             Analyst Programmer
# 249             Research Associate
#
# [250 rows x 8 columns]

# %% [markdown]
# ------
