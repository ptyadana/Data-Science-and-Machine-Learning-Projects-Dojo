# %% [markdown]
# # 1) Memory Optimization

# %%
import pandas as pd

# %%
df = pd.read_csv('Data/employees.csv')
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %% [markdown]
# ### After checking the info of our dataframe,
# + there are some columns with missing data
# + Start Date and Last Login Time are imported as Object(string) type. This will prevent us from using DateTime related methods in the future. So we need to convert them to correct datatype.
# + Senior Management are True/False value , however it is currently in object.
# + Team and Gender are in object, we can use category data type.

# %% [markdown]
# ## Converting to datetime using `pd.to_datetime()` Method

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])
df['Start Date']
# Out:
# 0     1993-08-06
# 1     1996-03-31
# 2     1993-04-23
# 3     2005-03-04
# 4     1998-01-24
#          ...
# 995   2014-11-23
# 996   1984-01-31
# 997   2013-05-20
# 998   2013-04-20
# 999   2012-05-15
# Name: Start Date, Length: 1000, dtype: datetime64[ns]

# %% [markdown]
# ### For Last Login Time, we only have time without date. So when converting to datetime, it gonna use today date by default. This is ok for our currenty case.

# %%
df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Last Login Time'].head(3)
# Out:
# 0   2021-04-04 12:42:00
# 1   2021-04-04 06:53:00
# 2   2021-04-04 11:17:00
# Name: Last Login Time, dtype: datetime64[ns]

# %% [markdown]
# ### Converting Senior Managment to Boolean data type

# %%
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Senior Management']
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Senior Management, Length: 1000, dtype: bool

# %% [markdown]
# ### Converting Gender to category

# %%
df['Gender'] = df['Gender'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-04-04 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-04-04 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %% [markdown]
# ### convert Team to category

# %%
df['Team'].value_counts()
# Out:
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: Team, dtype: int64

# %%
df['Team'] = df['Team'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %% [markdown]
# ## Converting datetime during `parse_dates` during reading csv

# %%
df = pd.read_csv('Data/employees.csv', parse_dates=['Start Date', 'Last Login Time'])

# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team'] = df['Team'].astype('category')

df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-04-04 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-04-04 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %% [markdown]
# ------

# %% [markdown]
# # 2) Filter a DataFrame Based on a Condition

# %%
df = pd.read_csv('Data/employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team'] = df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-04-04 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-04-04 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df['Gender'] == 'Male'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
df[df['Gender'] == 'Male']
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2021-04-04 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2021-04-04 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2021-04-04 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2021-04-04 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2021-04-04 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2021-04-04 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2021-04-04 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2021-04-04 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2021-04-04 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 3                 True               Finance
# 4                 True       Client Services
# 5                False                 Legal
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [424 rows x 8 columns]

# %%
# more elegant way

is_finance = df['Team'] == 'Finance'
df[is_finance]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2021-04-04 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-04-04 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2021-04-04 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2021-04-04 07:13:00   41426   14.543
# 46       Bruce    Male 2009-11-28 2021-04-04 22:47:00  114796    6.796
# ..         ...     ...        ...                 ...     ...      ...
# 907  Elizabeth  Female 1998-07-27 2021-04-04 11:12:00  137144   10.081
#
#      Senior Management             Team
# 10                True              NaN
# 12                True  Human Resources
# 18               False  Client Services
# 28                True  Client Services
# 37                True  Client Services
# ..                 ...              ...
# 982               True  Human Resources
# 983              False      Engineering
# 985              False            Legal
# 986              False        Marketing
# 996              False          Finance
#
# [133 rows x 8 columns]

# %% [markdown]
# --------

# %% [markdown]
# # 3) Filter with More than One Condition (AND `&`)

# %%
df = pd.read_csv('Data/employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team'] = df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-04-04 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-04-04 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %% [markdown]
# ### If we were handling more than one conditions, it is recommended to put each condition in separate variable, insteading of stacking

# %%
is_male = df['Gender'] == 'Male'
is_marketing = df['Team'] == 'Marketing'

df[is_male & is_marketing] # both
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2021-04-04 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2021-04-04 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2021-04-04 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2021-04-04 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2021-04-04 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2021-04-04 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2021-04-04 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2021-04-04 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2021-04-04 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2021-04-04 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2021-04-04 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2021-04-04 09:45:00   55281    4.935
# 216    Matthew   Male 2013-07-31 2021-04-04 08:04:00  142373    2.462
# 252      Ralph   Male 2004-11-11 2021-04-04 01:35:00   71896    4.232
# 274     Howard   Male 1982-10-05 2021-04-04 07:22:00   97490    5.460
# 293      Jesse   Male 1999-10-25 2021-04-04 15:35:00  118733    9.653
# 309   Benjamin   Male 1984-09-11 2021-04-04 06:37:00   84810   15.794
# 327      Aaron   Male 1994-01-29 2021-04-04 18:48:00   58755    5.097
# 353        NaN   Male 1997-04-22 2021-04-04 21:36:00   65078    3.095
# 403      Craig   Male 1984-02-08 2021-04-04 04:45:00  113506   19.642
# 413     Johnny   Male 1992-09-14 2021-04-04 08:21:00  115194    5.861
# 452      Scott   Male 2012-11-17 2021-04-04 14:47:00  146812    1.965
# 454        NaN   Male 1995-02-21 2021-04-04 00:26:00  136602   10.429
# 461     Jeremy   Male 2001-08-09 2021-04-04 03:56:00   43354   13.946
# 464   Lawrence   Male 2005-05-13 2021-04-04 01:25:00   74640   18.641
# 484        Joe   Male 2000-04-14 2021-04-04 15:14:00   50645   11.119
# 496     Johnny   Male 2016-02-26 2021-04-04 19:39:00   76394    5.437
# 503      Roger   Male 2015-08-03 2021-04-04 16:56:00  125033    4.887
# 544      Roger   Male 2010-07-03 2021-04-04 17:11:00  105689   13.320
# 550    Gregory   Male 1984-06-18 2021-04-04 03:46:00   82726   16.304
# 556     Arthur   Male 2014-12-16 2021-04-04 16:56:00   66819    6.639
# 571   Jonathan   Male 1995-04-06 2021-04-04 22:38:00   56993   18.623
# 581     Ernest   Male 1990-01-28 2021-04-04 00:08:00   81919   15.118
# 696     Samuel   Male 2012-05-25 2021-04-04 16:40:00   85550   11.593
# 722     Joshua   Male 1997-06-27 2021-04-04 15:23:00   95003    5.197
# 798   Lawrence   Male 1984-10-01 2021-04-04 14:06:00  102589   17.952
# 860    Phillip   Male 1984-10-07 2021-04-04 11:05:00   36837   14.660
# 867       Earl   Male 2013-06-15 2021-04-04 03:00:00   48046    7.737
# 899     Walter   Male 1992-05-21 2021-04-04 00:39:00  144701   16.323
# 947        NaN   Male 2012-07-30 2021-04-04 15:07:00  107351    5.329
# 994     George   Male 2013-06-21 2021-04-04 17:47:00   98874    4.479
#
#      Senior Management       Team
# 0                 True  Marketing
# 21               False  Marketing
# 26                True  Marketing
# 74               False  Marketing
# 77                True  Marketing
# 101               True  Marketing
# 104              False  Marketing
# 112              False  Marketing
# 119              False  Marketing
# 150              False  Marketing
# 187              False  Marketing
# 204               True  Marketing
# 216              False  Marketing
# 252               True  Marketing
# 274               True  Marketing
# 293              False  Marketing
# 309              False  Marketing
# 327               True  Marketing
# 353               True  Marketing
# 403              False  Marketing
# 413               True  Marketing
# 452               True  Marketing
# 454               True  Marketing
# 461              False  Marketing
# 464              False  Marketing
# 484              False  Marketing
# 496               True  Marketing
# 503               True  Marketing
# 544               True  Marketing
# 550               True  Marketing
# 556               True  Marketing
# 571              False  Marketing
# 581              False  Marketing
# 696               True  Marketing
# 722               True  Marketing
# 798               True  Marketing
# 860              False  Marketing
# 867              False  Marketing
# 899               True  Marketing
# 947               True  Marketing
# 994               True  Marketing

# %% [markdown]
# ---

# %% [markdown]
# # 4) Filter with More than One Condition (OR `|`)

# %%
df = pd.read_csv('Data/employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team'] = df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-04-04 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-04-04 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
is_senior_managment = df['Senior Management']
is_less_than_1990Jan1 = df['Start Date'] < '1990-01-01'

df[is_senior_managment | is_less_than_1990Jan1] # either one
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-04-04 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2021-04-04 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-04-04 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2021-04-04 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 992    Anthony    Male 2011-10-16 2021-04-04 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2021-04-04 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2021-04-04 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2021-04-04 06:30:00   42392   19.675
# 999     Albert    Male 2012-05-15 2021-04-04 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# 1                 True              NaN
# 3                 True          Finance
# 4                 True  Client Services
# 5                False            Legal
# ..                 ...              ...
# 992               True          Finance
# 993               True      Engineering
# 994               True        Marketing
# 996              False          Finance
# 999               True            Sales
#
# [653 rows x 8 columns]

# %%
mask1 = df['First Name'] == 'Robert'
mask2 = df['Team'] == 'Client Services'
mask3 = df['Start Date'] > '2016-06-01'

df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2021-04-04 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2021-04-04 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2021-04-04 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2021-04-04 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# ------

# %% [markdown]
# # 5) The `.isin()` Method

# %%
df = pd.read_csv('Data/employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team'] = df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-04-04 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-04-04 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
mask1 = df['Team'] == 'Legal'
mask2 = df['Team'] == 'Sales'
mask3 = df['Team'] == 'Product'

df[mask1 | mask2 | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2021-04-04 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2021-04-04 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2021-04-04 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2021-04-04 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2021-04-04 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2021-04-04 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2021-04-04 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2021-04-04 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2021-04-04 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2021-04-04 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# 11                True    Legal
# 13               False    Sales
# 15               False  Product
# ..                 ...      ...
# 981              False    Legal
# 985              False    Legal
# 989              False    Legal
# 997              False  Product
# 999               True    Sales
#
# [277 rows x 8 columns]

# %% [markdown]
# ### Instead we can do more efficiently with `.isin()` Method
# + it not only takes python list, but also pandas series

# %%
mask = df['Team'].isin(['Legal', 'Product', 'Marketing'])
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06
# 580        Harry    Male 1985-01-27 2021-04-04 20:18:00   65482   18.089
# 626          NaN  Female 1997-04-13 2021-04-04 08:03:00  131755    2.930
# 634         Carl    Male 1987-03-30 2021-04-04 17:59:00   75598   19.289
# 635        Randy    Male 2000-09-27 2021-04-04 03:04:00   89831   13.047
# 647       Donald    Male 1988-04-06 2021-04-04 10:00:00  122920    5.320
# 669       Joseph     NaN 1982-03-28 2021-04-04 13:05:00   86564   11.879
# 684        Alice  Female 2016-01-21 2021-04-04 17:07:00  117787   10.485
# 706         Todd    Male 1993-07-04 2021-04-04 18:53:00  128175   18.473
# 726       Daniel    Male 2016-02-29 2021-04-04 04:04:00   77287   13.000
# 753      Antonio    Male 1999-06-06 2021-04-04 22:54:00   41928    5.478
# 774          NaN  Female 2000-06-18 2021-04-04 07:36:00  106428   10.867
# 781     Lawrence    Male 1995-07-03 2021-04-04 22:55:00   46378    9.127
# 794       Nicole  Female 2004-03-01 2021-04-04 17:17:00   44021   10.286
# 826          NaN     NaN 1988-08-01 2021-04-04 01:35:00   87103    5.665
# 850      Charles    Male 1997-09-03 2021-04-04 10:04:00  148291    6.002
# 851        Bobby    Male 1996-08-19 2021-04-04 01:16:00  147842   16.158
# 853      Mildred  Female 2007-04-06 2021-04-04 22:06:00  139284   11.390
# 855      Phillip     NaN 2003-10-20 2021-04-04 11:09:00   89700    2.277
# 864         Ryan    Male 2012-11-16 2021-04-04 13:47:00   57292    6.010
# 912          Joe    Male 1998-12-08 2021-04-04 10:28:00  126120    1.020
# 951          NaN  Female 2010-09-14 2021-04-04 05:19:00  143638    9.662
#
#      Senior Management Team
# 1                 True  NaN
# 10                True  NaN
# 23                True  NaN
# 32                True  NaN
# 91               False  NaN
# 109              False  NaN
# 139               True  NaN
# 199               True  NaN
# 258              False  NaN
# 290               True  NaN
# 314              False  NaN
# 367               True  NaN
# 382               True  NaN
# 434               True  NaN
# 438               True  NaN
# 445              False  NaN
# 479               True  NaN
# 512              False  NaN
# 513              False  NaN
# 520               True  NaN
# 567               True  NaN
# 573               True  NaN
# 580              False  NaN
# 626               True  NaN
# 634              False  NaN
# 635               True  NaN
# 647              False  NaN
# 669               True  NaN
# 684              False  NaN
# 706               True  NaN
# 726               True  NaN
# 753               True  NaN
# 774               True  NaN
# 781              False  NaN
# 794              False  NaN
# 826               True  NaN
# 850              False  NaN
# 851               True  NaN
# 853               True  NaN
# 855               True  NaN
# 864              False  NaN
# 912              False  NaN
# 951               True  NaN

# %%
df.isnull().sum()
# Out:
# First Name            67
# Gender               145
# Start Date             0
# Last Login Time        0
# Salary                 0
# Bonus %                0
# Senior Management      0
# Team                  43
# dtype: int64

# %%
is_gender_not_null = df['Gender'].notnull() # gender not null rows
df[is_gender_not_null]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-04-04 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2021-04-04 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-04-04 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-04-04 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2021-04-04 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2021-04-04 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2021-04-04 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2021-04-04 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2021-04-04 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# 1                 True                   NaN
# 2                False               Finance
# 3                 True               Finance
# 4                 True       Client Services
# ..                 ...                   ...
# 994               True             Marketing
# 996              False               Finance
# 997              False               Product
# 998              False  Business Development
# 999               True                 Sales
#
# [855 rows x 8 columns]

# %% [markdown]
# -------

# %% [markdown]
# # 7) The `.between()` Method
#
# **helpful to use to search the values between a Range whether it is Time, etc**

# %%
df = pd.read_csv('Data/employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team'] = df['Team'].astype('category')
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-04-04 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-04-04 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df[df['Salary'].between(60000, 70000)] # values are INCLUSIVE
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2021-04-04 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2021-04-04 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2021-04-04 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2021-04-04 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2021-04-04 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2021-04-04 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2021-04-04 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2021-04-04 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2021-04-04 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# 6                 True               Product
# 10                True                   NaN
# 20                True                 Legal
# 41                True  Business Development
# ..                 ...                   ...
# 965              False       Client Services
# 970               True               Product
# 974               True       Client Services
# 978              False       Human Resources
# 998              False  Business Development
#
# [86 rows x 8 columns]

# %%
df[df['Bonus %'].between(2.0, 5.0)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 20        Lois     NaN 1995-04-22 2021-04-04 19:18:00   64714    4.934
# 40     Michael    Male 2008-10-10 2021-04-04 11:25:00   99283    2.665
# 49       Chris     NaN 1980-01-24 2021-04-04 12:13:00  113590    3.055
# 60       Paula     NaN 2005-11-23 2021-04-04 14:01:00   48866    4.271
# ..         ...     ...        ...                 ...     ...      ...
# 943      Wayne    Male 2006-09-08 2021-04-04 11:09:00   67471    2.728
# 961    Antonio     NaN 1989-06-18 2021-04-04 21:37:00  103050    3.050
# 976     Denise  Female 1992-10-19 2021-04-04 05:42:00  137954    4.195
# 989     Justin     NaN 1991-02-10 2021-04-04 16:58:00   38344    3.794
# 994     George    Male 2013-06-21 2021-04-04 17:47:00   98874    4.479
#
#      Senior Management          Team
# 1                 True           NaN
# 20                True         Legal
# 40                True  Distribution
# 49               False         Sales
# 60               False  Distribution
# ..                 ...           ...
# 943              False   Engineering
# 961              False         Legal
# 976               True         Legal
# 989              False         Legal
# 994               True     Marketing
#
# [169 rows x 8 columns]

# %% [markdown]
# ## `.between()` works with DateTime too

# %%
df[df['Start Date'].between('1991-01-01', '1991-12-31')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
#

# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2021-04-04 11:17:00  130590   11.858
# 7          NaN  Female 2015-07-20 2021-04-04 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2021-04-04 09:01:00   63241   15.132
# 18       Diana  Female 1981-10-23 2021-04-04 10:27:00  132940   19.082
# 33        Jean  Female 1993-12-18 2021-04-04 09:07:00  119082   16.180
# ..         ...     ...        ...                 ...     ...      ...
# 963        Ann  Female 1994-09-23 2021-04-04 11:15:00   89443   17.940
# 977      Sarah  Female 1995-12-04 2021-04-04 09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06 2021-04-04 10:43:00   91411    8.639
# 988      Alice  Female 2004-10-05 2021-04-04 09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16 2021-04-04 08:35:00  112769   11.625
#
#      Senior Management                  Team
# 2                False               Finance
# 7                 True               Finance
# 10                True                   NaN
# 18               False       Client Services
# 33               False  Business Development
# ..                 ...                   ...
# 963               True                 Sales
# 977              False               Product
# 982               True       Human Resources
# 988              False       Human Resources
# 992               True               Finance
#
# [136 rows x 8 columns]

# %% [markdown]
# --------

# %% [markdown]
# # The `.duplicated()` Method

# %%
df = pd.read_csv('Data/employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team'] = df['Team'].astype('category')
df = df.sort_values('First Name')
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2021-04-04 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2021-04-04 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2021-04-04 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %%
df['First Name']
# Out:
# 101    Aaron
# 327    Aaron
# 440    Aaron
# 937    Aaron
# 137     Adam
#        ...
# 902      NaN
# 925      NaN
# 946      NaN
# 947      NaN
# 951      NaN
# Name: First Name, Length: 1000, dtype: object

# %% [markdown]
# ## `dupicated()` method has parameter `keep`
# + by default, **`keep=first`** which keep the first value among duplicated values
#     + Example: name Aaron has duplicate values. When pandas find first value `Aaron`, it hasn't seen any `Aaron` value yet. So it is marked as False for duplicated. For the subsequent values of `Aaron`, those will be marked as True for duplicated.
# +**`keep=last`**: keep only the last value among the duplicated values. Other rows will be returned as True.
# + **`keep=False`**: mark rows which has duplicated values and return those.

# %% [markdown]
# ### using `keep=first`

# %%
df['First Name'].duplicated()
df['First Name'].duplicated(keep='first')
# Out:
# 101    False
# 327     True
# 440     True
# 937     True
# 137    False
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951     True
# Name: First Name, Length: 1000, dtype: bool

# %%
df[df['First Name'].duplicated()] # without first row 101 because it was kept
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male 1994-01-29 2021-04-04 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2021-04-04 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2021-04-04 19:39:00   63126   18.424
# 141       Adam    Male 1990-12-24 2021-04-04 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2021-04-04 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2021-04-04 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2021-04-04 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2021-04-04 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2021-04-04 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2021-04-04 05:19:00  143638    9.662
#
#      Senior Management             Team
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 141               True          Product
# 302               True  Human Resources
# ..                 ...              ...
# 902               True     Distribution
# 925               True            Sales
# 946               True     Distribution
# 947               True        Marketing
# 951               True              NaN
#
# [799 rows x 8 columns]

# %% [markdown]
# ### using `keep=last`

# %%
df['First Name'].duplicated(keep='last')
# Out:
# 101     True
# 327     True
# 440     True
# 937    False
# 137     True
#        ...
# 902     True
# 925     True
# 946     True
# 947     True
# 951    False
# Name: First Name, Length: 1000, dtype: bool

# %%
df[df['First Name'].duplicated(keep='last')] # without last row 937 for Aaron, because it was kept
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2021-04-04 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2021-04-04 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2021-04-04 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2021-04-04 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2021-04-04 20:57:00  110194   14.727
# ..         ...     ...        ...                 ...     ...      ...
# 890        NaN    Male 2015-11-24 2021-04-04 03:11:00  145329    7.100
# 902        NaN    Male 2001-05-23 2021-04-04 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2021-04-04 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2021-04-04 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2021-04-04 15:07:00  107351    5.329
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 137              False     Distribution
# 141               True          Product
# ..                 ...              ...
# 890               True          Finance
# 902               True     Distribution
# 925               True            Sales
# 946               True     Distribution
# 947               True        Marketing
#
# [799 rows x 8 columns]

# %% [markdown]
# ### using `keep=False`

# %%
df['First Name']
# Out:
# 101    Aaron
# 327    Aaron
# 440    Aaron
# 937    Aaron
# 137     Adam
#        ...
# 902      NaN
# 925      NaN
# 946      NaN
# 947      NaN
# 951      NaN
# Name: First Name, Length: 1000, dtype: object

# %%
df['First Name'].duplicated(keep=False)
# Out:
# 101    True
# 327    True
# 440    True
# 937    True
# 137    True
#        ...
# 902    True
# 925    True
# 946    True
# 947    True
# 951    True
# Name: First Name, Length: 1000, dtype: bool

# %%
df[df['First Name'].duplicated(keep=False)] # all rows with duplicated rows will be returned without keeping them, so that those can be handled later
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2021-04-04 10:20:00   61602   11.849
# 327      Aaron    Male 1994-01-29 2021-04-04 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2021-04-04 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2021-04-04 19:39:00   63126   18.424
# 137       Adam    Male 2011-05-21 2021-04-04 01:45:00   95327   15.120
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2021-04-04 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2021-04-04 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2021-04-04 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2021-04-04 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2021-04-04 05:19:00  143638    9.662
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution
# ..                 ...              ...
# 902               True     Distribution
# 925               True            Sales
# 946               True     Distribution
# 947               True        Marketing
# 951               True              NaN
#
# [991 rows x 8 columns]

# %% [markdown]
# ------

# %% [markdown]
# # Negating the conditions using `~` tilde

# %% [markdown]
# ## We want to get all rows which has unique values in First Name
# + Meaning negating all duplicated values in First Name rows are filtered out
# + the values that are only have unique values

# %%
unique_first_name_rows = ~df['First Name'].duplicated(keep=False)
df[unique_first_name_rows]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2021-04-04 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2021-04-04 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2021-04-04 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2021-04-04 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2021-04-04 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2021-04-04 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2021-04-04 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2021-04-04 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2021-04-04 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %% [markdown]
# ----

# %% [markdown]
# # 9) The `.drop_duplicates()` Method

# %%
df = pd.read_csv('Data/employees.csv', parse_dates=['Start Date', 'Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team'] = df['Team'].astype('category')
df = df.sort_values('First Name')
df.head(3)
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2021-04-04 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2021-04-04 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2021-04-04 14:53:00   52119   11.343
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services

# %% [markdown]
# ### After we call drop_duplicates() on our dataframe (deduplicated), why the length is still 1000?
# Because:
# + It doesn't matter if there are duplicates in a Single column (example: we have so many Aaron in First Name column, we know we have duplicates in Gender, we know we have duplicates in Senior Management)
# + **It only remove the row if cell values across the columns are identical, to another row or more than 2 rows**
# + So there is no such rows in our df. We only have rows (maybe values for 1 column or 2 columns or even 5 columns values are same in another rows).
# + So no rows are being removed by default.
# + **We have to provide a little more customization in order to get what we want.**

# %%
len(df)
# Out:
# 1000

# %%
len(df.drop_duplicates())
# Out:
# 1000

# %% [markdown]
# ### providing customization for `.drop_duplicates()`
# + `subset`, `keep`

# %%
df.drop_duplicates(subset=['First Name'], keep='first') # keep only the first Aaron
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aa
# 832      Keith    Male 2003-02-12 2021-04-04 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2021-04-04 10:30:00  132839   17.463
#
#      Senior Management                  Team
# 8                 True           Engineering
# 688               True                 Legal
# 190              False               Finance
# 887              False                 Legal
# 5                False                 Legal
# 495              False                 Sales
# 33               False  Business Development
# 832              False                 Legal
# 291               True       Client Services

# %% [markdown]
# ### If we are not careful using this method, funny thing might happen.
# Example: try to remove duplicates on Team column and only want to keep unique values

# %%
df.drop_duplicates(subset=['Team'], keep=False) # this will return empty data frame
# Out:
# Empty DataFrame
# Columns: [First Name, Gender, Start Date, Last Login Time, Salary, Bonus %, Senior Management, Team]
# Index: []

# %% [markdown]
# ### More than one values for subset

# %%
df.drop_duplicates(subset=['First Name', 'Team']) # unique rows across First Name and Team
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2021-04-04 10:20:00   61602   11.849
# 440      Aaron    Male 1990-07-22 2021-04-04 14:53:00   52119   11.343
# 137       Adam    Male 2011-05-21 2021-04-04 01:45:00   95327   15.120
# 141       Adam    Male 1990-12-24 2021-04-04 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2021-04-04 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 149        NaN  Female 2014-08-17 2021-04-04 14:00:00   86230    8.578
# 157        NaN  Female 2005-07-27 2021-04-04 08:32:00   79536   14.443
# 269        NaN  Female 1992-08-02 2021-04-04 20:35:00  145316   18.517
# 329        NaN    Male 2010-01-27 2021-04-04 02:57:00   87760   14.987
# 481        NaN  Female 2013-04-27 2021-04-04 06:40:00   93847    1.085
#
#      Senior Management                  Team
# 101               True             Marketing
# 440               True       Client Services
# 137              False          Distribution
# 141               True               Product
# 302               True       Human Resources
# ..                 ...                   ...
# 149               True          Distribution
# 157               True               Product
# 269               True       Human Resources
# 329               True           Engineering
# 481               True  Business Development
#
# [769 rows x 8 columns]

# %% [markdown]
# --------

# %% [markdown]
# # 10) The `.unique()` and `.nunique()` Method

# %%
df = pd.read_csv('Data/employees.csv', parse_dates=['Start Date', 'Last Login Time'])

df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')
df['Team'] = df['Team'].astype('category')

df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-04-04 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-04-04 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-04-04 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %% [markdown]
# ### get the unique of columns

# %%
df['Gender'].unique()

df['Team'].unique()
# Out:
# ['Marketing', NaN, 'Finance', 'Client Services', 'Legal', ..., 'Engineering', 'Business Development', 'Human Resources', 'Sales', 'Distribution']
# Length: 11
# Categories (10, object): ['Marketing', 'Finance', 'Client Services', 'Legal', ..., 'Business Development', 'Human Resources', 'Sales', 'Distribution']

# %% [markdown]
# ### get the Number of Unique values
# + `dropna=True/False`: whether to count NaN or not

# %%
len(df['Team'].unique())
# Out:
# 11

# %%
df['Team'].nunique() # by default it doesn't count NaN values
df['Team'].nunique(dropna=True)
# Out:
# 10

# %%
df['Team'].nunique(dropna=False)
# Out:
# 11
